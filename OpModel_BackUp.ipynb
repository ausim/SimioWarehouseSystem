# %% [markdown]
# # MILP for COPP

# %%
# import modules
from gurobipy import *
import numpy as np
import pandas as pd
import pyodbc
import re

# %%
# connect to the database
conn_str = 'DSN=JDATA;database=WarehouseModel;Trusted_Connection=yes;'
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# %%
# get data from database
lineItem = pd.read_sql("SELECT ItemID FROM LineItem", conn)
pickers = pd.read_sql("SELECT PickerID, Speed, Capacity, PlaceTime FROM Pickers", conn)
transporters = pd.read_sql("SELECT TransporterID, Speed, Capacity, UnloadTime FROM Transporters", conn)
Sku_L = pd.read_sql("SELECT LineItem.ItemID, Skus.PickNodeID FROM LineItem INNER JOIN Skus ON LineItem.SkuID = Skus.SkuID", conn)
Nodes = pd.read_sql("SELECT ID, Node FROM Nodes WHERE NOT Type='MyTransferNode' AND NOT Type='MyDepotNode'", conn)
# dataframe and list of all physic nodes (Home, Picking locations, Handoff spots, Depot)
PhyNodes = pd.read_sql("SELECT Node FROM Nodes WHERE NOT Type='MyTransferNode'", conn)
PhyNodes_list = PhyNodes['Node'].tolist()
# get some setting paras
# number of items
NumItems = len(lineItem)
# number of depot replicas
DReps = 10
# depots dataframe
Depots = pd.DataFrame(list(range(1,DReps+1)), columns = ['Reps'])
# get travel time matrix from TimeMatrix.xlsx
Time_matrix = pd.read_excel('TimeMatrix.xlsx', sheet_name = 'TimeMatrix', header=None).fillna(0)

# %% [markdown]
# ## Gurobi Model

# %%
# create empty model object
model = Model('COPP')
# set time limit for optimization
model.setParam('TimeLimit', 60)
# Out:
# Changed value of parameter TimeLimit to 60.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf

# %% [markdown]
# ### Parameters and keys

# %%
# define the speed, capacity, place time for each picker
_, Vp, Cp, PLT = multidict(pickers.set_index(['PickerID'])[['Speed','Capacity','PlaceTime']].T.to_dict('list'))
# define the speed, capacity, unload time for each transporter
_, Vt, Ct, ULT = multidict(transporters.set_index(['TransporterID'])[['Speed','Capacity','UnloadTime']].T.to_dict('list'))

# Some useful dataframes
P = pickers[['PickerID']]  # pickers
T = transporters[['TransporterID']] # transporters
I = lineItem  # items
HR = Nodes.drop(0) # all physical handoff spots
# all picking locations
RI = pd.DataFrame(Sku_L.apply(lambda x: 'MyPickNode'+str(x['PickNodeID'])+'_PL'+str(x['ItemID']), axis = 1), columns=['Node'])
HRI = pd.DataFrame() # all handoff replicas
#complete HRI df
for i in range(NumItems):
    HRi = HR.copy()
    HRi['Node'] = HRi['Node'] + '_I'+str(i+1)
    HRI = HRI.append(HRi,ignore_index=True)
# depot replicas
D = pd.DataFrame(Depots.apply(lambda x: 'DepotRep_'+ str(x['Reps']), axis =1), columns = ['Reps'])

# %% [markdown]
# ## Decision Variables

# %% [markdown]
# ### Makespan decision variable -- m

# %%
m =  model.addVar(vtype=GRB.CONTINUOUS, name = 'm')

# %% [markdown]
# ### Assignment decision variables -- a[e1, e2, i]

# %%
# define the set of all items, pickers and transporters. For decision variable a[e1,e2,i]
# e1: picker
# e2: transporter
# i: item
I_P = pd.merge(I, P, how='cross')
I_P_T = pd.merge(I_P , T, how='cross')
I_P_T['Cell'] = 1
# create dicts for decision variable
Da, _ = multidict(I_P_T.set_index(['PickerID', 'TransporterID', 'ItemID']).to_dict()['Cell'])
# create the decision variable
a = model.addVars(Da, vtype=GRB.BINARY, name = 'A')

# %% [markdown]
# ### Picker item sequence decision variables -- X[e1, i, j]

# %%
# define the set of all pickers and item picking sequence segments. For decision variabel X[e1,i,j]
# e1: picker
# i: picking item (item 0 is the virtual start item)
# l: next picking item (item -1 is the virtual end item)
I_I = pd.merge(I, I, how='cross')
I_I['Keep']=I_I.apply(lambda x: False if x['ItemID_x'] == x['ItemID_y'] else True, axis = 1)
I_I = I_I[I_I['Keep']].reset_index(drop=True)
# add virtual items sequences
for i in range(1,NumItems+1):
    I_I.loc[len(I_I.index)] = [0, i, True]
for i in range(1,NumItems+1):
    I_I.loc[len(I_I.index)] = [i,-1, True]    
P_I_I = pd.merge(P,I_I, how='cross')
P_I_I.columns = ['e1','i','j','Keep']

# create dicts for decision variable
DX, _ = multidict(P_I_I.set_index(['e1', 'i', 'j']).to_dict()['Keep'])
# create the decision variable
X = model.addVars(DX, vtype=GRB.BINARY, name = 'X')

# %% [markdown]
# ### Picker node sequence decision variables -- Y[e1, k ,k1]

# %%
# define the sets of all pickers and travel segements. For decision Variable Y[e1,k,k1]
# e1: picker
# k: previous node
# k1: next node (Picking location, Handoff spots replicas, Home node replicas)

# set when k1 is handoff replicas
# complete P_RI_HRI df
# HR: the set of physical handoff spots
RI_HRI = pd.merge(Sku_L,HR, how='cross')
RI_HRI['k'] = RI_HRI.apply(lambda x: 'MyPickNode'+str(x['PickNodeID'])+'_PL'+str(x['ItemID']), axis = 1)
RI_HRI['k1'] = RI_HRI.apply(lambda x: x['Node']+'_I'+str(x['ItemID']), axis = 1)
P_RI_HRI = pd.merge(P,RI_HRI, how='cross')[['PickerID','k','k1']]
P_RI_HRI.columns = ['e1','k','k1']

# set when k1 is Picking node
# HRI: the set of all handoff spots replicas
# RI: the set of all picking locations
HRI_RI = pd.merge(Sku_L,HRI, how='cross')
HRI_RI['k1'] = HRI_RI.apply(lambda x: 'MyPickNode'+str(x['PickNodeID'])+'_PL'+str(x['ItemID']), axis = 1)
droplist = []
for i in range(len(HRI_RI)):
    if re.findall("\d+",HRI_RI.at[i,'Node'])[-1] == str(HRI_RI.at[i,'ItemID']):
        droplist.append(i)
HRI_RI = HRI_RI.drop(droplist)
P_HRI_RI = pd.merge(P,HRI_RI, how='cross')[['PickerID','Node','k1']]
P_HRI_RI.columns = ['e1','k','k1']
Hp = P.copy()
Hp.columns = ['e1']
Hp['k'] = Hp.apply(lambda x: 'MyHome_P'+str(x['e1']), axis =1)
P_H_RI = pd.merge(Hp,RI,how='cross')
P_H_RI.columns = ['e1','k','k1']
P_HHRI_RI = pd.concat([P_HRI_RI, P_H_RI], ignore_index=True)

# set when k1 is home node replicas
P_HRI_H = pd.merge(Hp, RI_HRI['k1'].to_frame('k'), how='cross')[['e1','k_y','k_x']]
P_HRI_H.columns = ['e1','k','k1']

# get the final sets and dict
Y_P = pd.concat([P_RI_HRI, P_HHRI_RI, P_HRI_H], ignore_index=True)
Y_P['Cell'] = 1
DYp, _ = multidict(Y_P.set_index(['e1', 'k', 'k1']).to_dict()['Cell'])

# create the decision variable
Yp = model.addVars(DYp, vtype=GRB.BINARY, name = 'Yp')

# %%
# define the function that set the time value for each node sequence
def setTimeforTLs_P(row):
    head_node = row['k'][:row['k'].index('_')]
    tail_node = row['k1'][:row['k1'].index('_')]
    head_id = PhyNodes_list.index(head_node)
    tail_id = PhyNodes_list.index(tail_node)
    return(Time_matrix.iloc[head_id, tail_id])

Y_P['Time'] = Y_P.apply(lambda x: setTimeforTLs_P(x), axis = 1)
# define travel time for each possible node sequence for picker
_, Lp = multidict(Y_P.set_index(['k', 'k1']).to_dict()['Time'])

# %% [markdown]
# ### Transporter node sequence decision variables -- Y[e2, k ,k1]

# %%
# define a function that is used to decide wheteher a node seuqnece (HRI_HRI) is feasible
def T_NodeSeqFeasibility(row):
    head_item = row['Node_x'][row['Node_x'].index('_'):]
    tail_item = row['Node_y'][row['Node_y'].index('_'):]
    if head_item == tail_item:
        return (False)
    else:
        return(True)

# %%
# define the sets of all transporters and travel segements. For decision Variable Y[e2,k,k1]
# e2: transporter
# k: previous node
# k1: next node (Depot replicas, Handoff spots replicas, Home node replicas)

# set when k1 is depot replicas
HRI_D = pd.merge(HRI, D, how='cross')
T_HRI_D = pd.merge(T, HRI_D[['Node','Reps']], how='cross')
T_HRI_D.columns = ['e2','k','k1']

# # set when k1 is home node replicas
Ht = T.copy()
Ht.columns = ['e2']
Ht['k1'] = Ht.apply(lambda x: 'MyHome_T'+str(x['e2']), axis =1)
D_H = pd.merge(D, Ht, how='cross')
T_D_H = D_H[['e2','Reps','k1']]
T_D_H.columns = ['e2','k','k1']

# set when k1 is handoff spots replicas
# when k is home node
H_HRI = pd.merge(Ht, HRI, how='cross')
T_H_HRI = H_HRI[['e2','k1','Node']]
T_H_HRI.columns = ['e2','k','k1']
# when k is depot replicas
D_HRI = pd.merge(D, HRI, how='cross')
# D_HRI['k'] = D_HRI.apply(lambda x: 'DepotRep_'+ str(x['Reps']), axis =1)
T_D_HRI = pd.merge(T, D_HRI, how='cross')[['TransporterID','Reps','Node']]
T_D_HRI.columns = ['e2','k','k1']
# when k is another handoff spots
HRI_HRI = pd.merge(HRI, HRI, how='cross')
HRI_HRI['Keep']=HRI_HRI.apply(lambda x: T_NodeSeqFeasibility(x), axis = 1)
HRI_HRI = HRI_HRI[HRI_HRI['Keep']].reset_index(drop=True)[['Node_x','Node_y']]
T_HRI_HRI = pd.merge(T,HRI_HRI, how='cross')
T_HRI_HRI.columns = ['e2','k','k1']

# get the final sets and dict
Y_T = pd.concat([T_H_HRI, T_HRI_D, T_D_HRI, T_D_H, T_HRI_HRI], ignore_index=True)
Y_T['Cell'] = 1
DYt, _ = multidict(Y_T.set_index(['e2', 'k', 'k1']).to_dict()['Cell'])

# create the decision variable
Yt = model.addVars(DYt, vtype=GRB.BINARY, name = 'Yt')

# %%
Y_T
# Out:
#        e2                k               k1  Cell
# 0       1        MyHome_T1   MyPickNode1_I1     1
# 1       1        MyHome_T1   MyPickNode2_I1     1
# 2       1        MyHome_T1   MyPickNode3_I1     1
# 3       1        MyHome_T1   MyPickNode4_I1     1
# 4       1        MyHome_T1   MyPickNode5_I1     1
# ...    ..              ...              ...   ...
# 89125   3  MyCoopNode12_I5   MyCoopNode8_I4     1
# 89126   3  MyCoopNode12_I5   MyCoopNode9_I4     1
# 89127   3  MyCoopNode12_I5  MyCoopNode10_I4     1
# 89128   3  MyCoopNode12_I5  MyCoopNode11_I4     1
# 89129   3  MyCoopNode12_I5  MyCoopNode12_I4     1
#
# [89130 rows x 4 columns]

# %% [markdown]
# ### Picker arrival time decision variables -- t[e1, k]

# %%
# All nodes that a picker may visit (exclude home node)
P_AllNodes = pd.concat([RI, HRI[['Node']]], ignore_index=True)
tp_df = pd.merge(pickers[['PickerID','Capacity']],P_AllNodes, how='cross' )
# create dicts for decision variable
Dtp, _ = multidict(tp_df.set_index(['PickerID','Node']).to_dict()['Capacity'])
# create the decision variable
tp = model.addVars(Dtp, vtype=GRB.CONTINUOUS, lb=0, name = 'tp')

# %% [markdown]
# ### Picker payload at node decision variables-- S[e1,k]

# %%
# create the decision variable
Sp = model.addVars(Dtp, vtype=GRB.INTEGER, ub = tp_df['Capacity'].tolist(), name = 'Sp')

# %% [markdown]
# ### Transporter arrival time decision variables -- t[e2, k]

# %%
# All nodes that a transporter may visit (exclude home node)
NewD = D.copy()
NewD.columns = ['Node']
T_AllNodes = pd.concat([NewD, HRI[['Node']]], ignore_index=True)
tt_df = pd.merge(transporters[['TransporterID','Capacity']],T_AllNodes, how='cross')
# create dicts for decision variable
Dtt, _ = multidict(tt_df.set_index(['TransporterID','Node']).to_dict()['Capacity'])
# create the decision variable
tt = model.addVars(Dtt, vtype=GRB.CONTINUOUS, lb=0, name = 'tt')

# %%
Dtt
# Out:
# <gurobi.tuplelist (570 tuples, 2 values each):
#  ( 1 , DepotRep_1      )
#  ( 1 , DepotRep_2      )
#  ( 1 , DepotRep_3      )
#  ( 1 , DepotRep_4      )
#  ( 1 , DepotRep_5      )
#  ( 1 , DepotRep_6      )
#  ( 1 , DepotRep_7      )
#  ( 1 , DepotRep_8      )
#  ( 1 , DepotRep_9      )
#  ( 1 , DepotRep_10     )
#  ( 1 , MyPickNode1_I1  )
#  ( 1 , MyPickNode2_I1  )
#  ( 1 , MyPickNode3_I1  )
#  ( 1 , MyPickNode4_I1  )
#  ( 1 , MyPickNode5_I1  )
#  ( 1 , MyPickNode6_I1  )
#  ( 1 , MyPickNode7_I1  )
#  ( 1 , MyPickNode8_I1  )
#  ( 1 , MyPickNode9_I1  )
#  ( 1 , MyPickNode10_I1 )
#  ( 1 , MyPickNode11_I1 )
#  ( 1 , MyPickNode12_I1 )
#  ( 1 , MyPickNode13_I1 )
#  ( 1 , MyPickNode14_I1 )
#  ( 1 , MyPickNode15_I1 )
#  ( 1 , MyPickNode16_I1 )
#  ( 1 , MyPickNode17_I1 )
#  ( 1 , MyPickNode18_I1 )
#  ( 1 , MyPickNode19_I1 )
#  ( 1 , MyPickNode20_I1 )
#  ( 1 , MyPickNode21_I1 )
#  ( 1 , MyPickNode22_I1 )
#  ( 1 , MyPickNode23_I1 )
#  ( 1 , MyPickNode24_I1 )
#  ( 1 , MyCoopNode1_I1  )
#  ( 1 , MyCoopNode2_I1  )
#  ( 1 , MyCoopNode3_I1  )
#  ( 1 , MyCoopNode4_I1  )
#  ( 1 , MyCoopNode5_I1  )
#  ( 1 , MyCoopNode6_I1  )
#  ( 1 , MyCoopNode7_I1  )
#  ( 1 , MyCoopNode8_I1  )
#  ( 1 , MyCoopNode9_I1  )
#  ( 1 , MyCoopNode10_I1 )
#  ( 1 , MyCoopNode11_I1 )
#  ( 1 , MyCoopNode12_I1 )
#  ( 1 , MyPickNode1_I2  )
#  ( 1 , MyPickNode2_I2  )
#  ( 1 , MyPickNode3_I2  )
#  ( 1 , MyPickNode4_I2  )
#  ( 1 , MyPickNode5_I2  )
#  ( 1 , MyPickNode6_I2  )
#  ( 1 , MyPickNode7_I2  )
#  ( 1 , MyPickNode8_I2  )
#  ( 1 , MyPickNode9_I2  )
#  ( 1 , MyPickNode10_I2 )
#  ( 1 , MyPickNode11_I2 )
#  ( 1 , MyPickNode12_I2 )
#  ( 1 , MyPickNode13_I2 )
#  ( 1 , MyPickNode14_I2 )
#  ( 1 , MyPickNode15_I2 )
#  ( 1 , MyPickNode16_I2 )
#  ( 1 , MyPickNode17_I2 )
#  ( 1 , MyPickNode18_I2 )
#  ( 1 , MyPickNode19_I2 )
#  ( 1 , MyPickNode20_I2 )
#  ( 1 , MyPickNode21_I2 )
#  ( 1 , MyPickNode22_I2 )
#  ( 1 , MyPickNode23_I2 )
#  ( 1 , MyPickNode24_I2 )
#  ( 1 , MyCoopNode1_I2  )
#  ( 1 , MyCoopNode2_I2  )
#  ( 1 , MyCoopNode3_I2  )
#  ( 1 , MyCoopNode4_I2  )
#  ( 1 , MyCoopNode5_I2  )
#  ( 1 , MyCoopNode6_I2  )
#  ( 1 , MyCoopNode7_I2  )
#  ( 1 , MyCoopNode8_I2  )
#  ( 1 , MyCoopNode9_I2  )
#  ( 1 , MyCoopNode10_I2 )
#  ( 1 , MyCoopNode11_I2 )
#  ( 1 , MyCoopNode12_I2 )
#  ( 1 , MyPickNode1_I3  )
#  ( 1 , MyPickNode2_I3  )
#  ( 1 , MyPickNode3_I3  )
#  ( 1 , MyPickNode4_I3  )
#  ( 1 , MyPickNode5_I3  )
#  ( 1 , MyPickNode6_I3  )
#  ( 1 , MyPickNode7_I3  )
#  ( 1 , MyPickNode8_I3  )
#  ( 1 , MyPickNode9_I3  )
#  ( 1 , MyPickNode10_I3 )
#  ( 1 , MyPickNode11_I3 )
#  ( 1 , MyPickNode12_I3 )
#  ( 1 , MyPickNode13_I3 )
#  ( 1 , MyPickNode14_I3 )
#  ( 1 , MyPickNode15_I3 )
#  ( 1 , MyPickNode16_I3 )
#  ( 1 , MyPickNode17_I3 )
#  ( 1 , MyPickNode18_I3 )
#  ( 1 , MyPickNode19_I3 )
#  ( 1 , MyPickNode20_I3 )
#  ( 1 , MyPickNode21_I3 )
#  ( 1 , MyPickNode22_I3 )
#  ( 1 , MyPickNode23_I3 )
#  ( 1 , MyPickNode24_I3 )
#  ( 1 , MyCoopNode1_I3  )
#  ( 1 , MyCoopNode2_I3  )
#  ( 1 , MyCoopNode3_I3  )
#  ( 1 , MyCoopNode4_I3  )
#  ( 1 , MyCoopNode5_I3  )
#  ( 1 , MyCoopNode6_I3  )
#  ( 1 , MyCoopNode7_I3  )
#  ( 1 , MyCoopNode8_I3  )
#  ( 1 , MyCoopNode9_I3  )
#  ( 1 , MyCoopNode10_I3 )
#  ( 1 , MyCoopNode11_I3 )
#  ( 1 , MyCoopNode12_I3 )
#  ( 1 , MyPickNode1_I4  )
#  ( 1 , MyPickNode2_I4  )
#  ( 1 , MyPickNode3_I4  )
#  ( 1 , MyPickNode4_I4  )
#  ( 1 , MyPickNode5_I4  )
#  ( 1 , MyPickNode6_I4  )
#  ( 1 , MyPickNode7_I4  )
#  ( 1 , MyPickNode8_I4  )
#  ( 1 , MyPickNode9_I4  )
#  ( 1 , MyPickNode10_I4 )
#  ( 1 , MyPickNode11_I4 )
#  ( 1 , MyPickNode12_I4 )
#  ( 1 , MyPickNode13_I4 )
#  ( 1 , MyPickNode14_I4 )
#  ( 1 , MyPickNode15_I4 )
#  ( 1 , MyPickNode16_I4 )
#  ( 1 , MyPickNode17_I4 )
#  ( 1 , MyPickNode18_I4 )
#  ( 1 , MyPickNode19_I4 )
#  ( 1 , MyPickNode20_I4 )
#  ( 1 , MyPickNode21_I4 )
#  ( 1 , MyPickNode22_I4 )
#  ( 1 , MyPickNode23_I4 )
#  ( 1 , MyPickNode24_I4 )
#  ( 1 , MyCoopNode1_I4  )
#  ( 1 , MyCoopNode2_I4  )
#  ( 1 , MyCoopNode3_I4  )
#  ( 1 , MyCoopNode4_I4  )
#  ( 1 , MyCoopNode5_I4  )
#  ( 1 , MyCoopNode6_I4  )
#  ( 1 , MyCoopNode7_I4  )
#  ( 1 , MyCoopNode8_I4  )
#  ( 1 , MyCoopNode9_I4  )
#  ( 1 , MyCoopNode10_I4 )
#  ( 1 , MyCoopNode11_I4 )
#  ( 1 , MyCoopNode12_I4 )
#  ( 1 , MyPickNode1_I5  )
#  ( 1 , MyPickNode2_I5  )
#  ( 1 , MyPickNode3_I5  )
#  ( 1 , MyPickNode4_I5  )
#  ( 1 , MyPickNode5_I5  )
#  ( 1 , MyPickNode6_I5  )
#  ( 1 , MyPickNode7_I5  )
#  ( 1 , MyPickNode8_I5  )
#  ( 1 , MyPickNode9_I5  )
#  ( 1 , MyPickNode10_I5 )
#  ( 1 , MyPickNode11_I5 )
#  ( 1 , MyPickNode12_I5 )
#  ( 1 , MyPickNode13_I5 )
#  ( 1 , MyPickNode14_I5 )
#  ( 1 , MyPickNode15_I5 )
#  ( 1 , MyPickNode16_I5 )
#  ( 1 , MyPickNode17_I5 )
#  ( 1 , MyPickNode18_I5 )
#  ( 1 , MyPickNode19_I5 )
#  ( 1 , MyPickNode20_I5 )
#  ( 1 , MyPickNode21_I5 )
#  ( 1 , MyPickNode22_I5 )
#  ( 1 , MyPickNode23_I5 )
#  ( 1 , MyPickNode24_I5 )
#  ( 1 , MyCoopNode1_I5  )
#  ( 1 , MyCoopNode2_I5  )
#  ( 1 , MyCoopNode3_I5  )
#  ( 1 , MyCoopNode4_I5  )
#  ( 1 , MyCoopNode5_I5  )
#  ( 1 , MyCoopNode6_I5  )
#  ( 1 , MyCoopNode7_I5  )
#  ( 1 , MyCoopNode8_I5  )
#  ( 1 , MyCoopNode9_I5  )
#  ( 1 , MyCoopNode10_I5 )
#  ( 1 , MyCoopNode11_I5 )
#  ( 1 , MyCoopNode12_I5 )
#  ( 2 , DepotRep_1      )
#  ( 2 , DepotRep_2      )
#  ( 2 , DepotRep_3      )
#  ( 2 , DepotRep_4      )
#  ( 2 , DepotRep_5      )
#  ( 2 , DepotRep_6      )
#  ( 2 , DepotRep_7      )
#  ( 2 , DepotRep_8      )
#  ( 2 , DepotRep_9      )
#  ( 2 , DepotRep_10     )
#  ( 2 , MyPickNode1_I1  )
#  ( 2 , MyPickNode2_I1  )
#  ( 2 , MyPickNode3_I1  )
#  ( 2 , MyPickNode4_I1  )
#  ( 2 , MyPickNode5_I1  )
#  ( 2 , MyPickNode6_I1  )
#  ( 2 , MyPickNode7_I1  )
#  ( 2 , MyPickNode8_I1  )
#  ( 2 , MyPickNode9_I1  )
#  ( 2 , MyPickNode10_I1 )
#  ( 2 , MyPickNode11_I1 )
#  ( 2 , MyPickNode12_I1 )
#  ( 2 , MyPickNode13_I1 )
#  ( 2 , MyPickNode14_I1 )
#  ( 2 , MyPickNode15_I1 )
#  ( 2 , MyPickNode16_I1 )
#  ( 2 , MyPickNode17_I1 )
#  ( 2 , MyPickNode18_I1 )
#  ( 2 , MyPickNode19_I1 )
#  ( 2 , MyPickNode20_I1 )
#  ( 2 , MyPickNode21_I1 )
#  ( 2 , MyPickNode22_I1 )
#  ( 2 , MyPickNode23_I1 )
#  ( 2 , MyPickNode24_I1 )
#  ( 2 , MyCoopNode1_I1  )
#  ( 2 , MyCoopNode2_I1  )
#  ( 2 , MyCoopNode3_I1  )
#  ( 2 , MyCoopNode4_I1  )
#  ( 2 , MyCoopNode5_I1  )
#  ( 2 , MyCoopNode6_I1  )
#  ( 2 , MyCoopNode7_I1  )
#  ( 2 , MyCoopNode8_I1  )
#  ( 2 , MyCoopNode9_I1  )
#  ( 2 , MyCoopNode10_I1 )
#  ( 2 , MyCoopNode11_I1 )
#  ( 2 , MyCoopNode12_I1 )
#  ( 2 , MyPickNode1_I2  )
#  ( 2 , MyPickNode2_I2  )
#  ( 2 , MyPickNode3_I2  )
#  ( 2 , MyPickNode4_I2  )
#  ( 2 , MyPickNode5_I2  )
#  ( 2 , MyPickNode6_I2  )
#  ( 2 , MyPickNode7_I2  )
#  ( 2 , MyPickNode8_I2  )
#  ( 2 , MyPickNode9_I2  )
#  ( 2 , MyPickNode10_I2 )
#  ( 2 , MyPickNode11_I2 )
#  ( 2 , MyPickNode12_I2 )
#  ( 2 , MyPickNode13_I2 )
#  ( 2 , MyPickNode14_I2 )
#  ( 2 , MyPickNode15_I2 )
#  ( 2 , MyPickNode16_I2 )
#  ( 2 , MyPickNode17_I2 )
#  ( 2 , MyPickNode18_I2 )
#  ( 2 , MyPickNode19_I2 )
#  ( 2 , MyPickNode20_I2 )
#  ( 2 , MyPickNode21_I2 )
#  ( 2 , MyPickNode22_I2 )
#  ( 2 , MyPickNode23_I2 )
#  ( 2 , MyPickNode24_I2 )
#  ( 2 , MyCoopNode1_I2  )
#  ( 2 , MyCoopNode2_I2  )
#  ( 2 , MyCoopNode3_I2  )
#  ( 2 , MyCoopNode4_I2  )
#  ( 2 , MyCoopNode5_I2  )
#  ( 2 , MyCoopNode6_I2  )
#  ( 2 , MyCoopNode7_I2  )
#  ( 2 , MyCoopNode8_I2  )
#  ( 2 , MyCoopNode9_I2  )
#  ( 2 , MyCoopNode10_I2 )
#  ( 2 , MyCoopNode11_I2 )
#  ( 2 , MyCoopNode12_I2 )
#  ( 2 , MyPickNode1_I3  )
#  ( 2 , MyPickNode2_I3  )
#  ( 2 , MyPickNode3_I3  )
#  ( 2 , MyPickNode4_I3  )
#  ( 2 , MyPickNode5_I3  )
#  ( 2 , MyPickNode6_I3  )
#  ( 2 , MyPickNode7_I3  )
#  ( 2 , MyPickNode8_I3  )
#  ( 2 , MyPickNode9_I3  )
#  ( 2 , MyPickNode10_I3 )
#  ( 2 , MyPickNode11_I3 )
#  ( 2 , MyPickNode12_I3 )
#  ( 2 , MyPickNode13_I3 )
#  ( 2 , MyPickNode14_I3 )
#  ( 2 , MyPickNode15_I3 )
#  ( 2 , MyPickNode16_I3 )
#  ( 2 , MyPickNode17_I3 )
#  ( 2 , MyPickNode18_I3 )
#  ( 2 , MyPickNode19_I3 )
#  ( 2 , MyPickNode20_I3 )
#  ( 2 , MyPickNode21_I3 )
#  ( 2 , MyPickNode22_I3 )
#  ( 2 , MyPickNode23_I3 )
#  ( 2 , MyPickNode24_I3 )
#  ( 2 , MyCoopNode1_I3  )
#  ( 2 , MyCoopNode2_I3  )
#  ( 2 , MyCoopNode3_I3  )
#  ( 2 , MyCoopNode4_I3  )
#  ( 2 , MyCoopNode5_I3  )
#  ( 2 , MyCoopNode6_I3  )
#  ( 2 , MyCoopNode7_I3  )
#  ( 2 , MyCoopNode8_I3  )
#  ( 2 , MyCoopNode9_I3  )
#  ( 2 , MyCoopNode10_I3 )
#  ( 2 , MyCoopNode11_I3 )
#  ( 2 , MyCoopNode12_I3 )
#  ( 2 , MyPickNode1_I4  )
#  ( 2 , MyPickNode2_I4  )
#  ( 2 , MyPickNode3_I4  )
#  ( 2 , MyPickNode4_I4  )
#  ( 2 , MyPickNode5_I4  )
#  ( 2 , MyPickNode6_I4  )
#  ( 2 , MyPickNode7_I4  )
#  ( 2 , MyPickNode8_I4  )
#  ( 2 , MyPickNode9_I4  )
#  ( 2 , MyPickNode10_I4 )
#  ( 2 , MyPickNode11_I4 )
#  ( 2 , MyPickNode12_I4 )
#  ( 2 , MyPickNode13_I4 )
#  ( 2 , MyPickNode14_I4 )
#  ( 2 , MyPickNode15_I4 )
#  ( 2 , MyPickNode16_I4 )
#  ( 2 , MyPickNode17_I4 )
#  ( 2 , MyPickNode18_I4 )
#  ( 2 , MyPickNode19_I4 )
#  ( 2 , MyPickNode20_I4 )
#  ( 2 , MyPickNode21_I4 )
#  ( 2 , MyPickNode22_I4 )
#  ( 2 , MyPickNode23_I4 )
#  ( 2 , MyPickNode24_I4 )
#  ( 2 , MyCoopNode1_I4  )
#  ( 2 , MyCoopNode2_I4  )
#  ( 2 , MyCoopNode3_I4  )
#  ( 2 , MyCoopNode4_I4  )
#  ( 2 , MyCoopNode5_I4  )
#  ( 2 , MyCoopNode6_I4  )
#  ( 2 , MyCoopNode7_I4  )
#  ( 2 , MyCoopNode8_I4  )
#  ( 2 , MyCoopNode9_I4  )
#  ( 2 , MyCoopNode10_I4 )
#  ( 2 , MyCoopNode11_I4 )
#  ( 2 , MyCoopNode12_I4 )
#  ( 2 , MyPickNode1_I5  )
#  ( 2 , MyPickNode2_I5  )
#  ( 2 , MyPickNode3_I5  )
#  ( 2 , MyPickNode4_I5  )
#  ( 2 , MyPickNode5_I5  )
#  ( 2 , MyPickNode6_I5  )
#  ( 2 , MyPickNode7_I5  )
#  ( 2 , MyPickNode8_I5  )
#  ( 2 , MyPickNode9_I5  )
#  ( 2 , MyPickNode10_I5 )
#  ( 2 , MyPickNode11_I5 )
#  ( 2 , MyPickNode12_I5 )
#  ( 2 , MyPickNode13_I5 )
#  ( 2 , MyPickNode14_I5 )
#  ( 2 , MyPickNode15_I5 )
#  ( 2 , MyPickNode16_I5 )
#  ( 2 , MyPickNode17_I5 )
#  ( 2 , MyPickNode18_I5 )
#  ( 2 , MyPickNode19_I5 )
#  ( 2 , MyPickNode20_I5 )
#  ( 2 , MyPickNode21_I5 )
#  ( 2 , MyPickNode22_I5 )
#  ( 2 , MyPickNode23_I5 )
#  ( 2 , MyPickNode24_I5 )
#  ( 2 , MyCoopNode1_I5  )
#  ( 2 , MyCoopNode2_I5  )
#  ( 2 , MyCoopNode3_I5  )
#  ( 2 , MyCoopNode4_I5  )
#  ( 2 , MyCoopNode5_I5  )
#  ( 2 , MyCoopNode6_I5  )
#  ( 2 , MyCoopNode7_I5  )
#  ( 2 , MyCoopNode8_I5  )
#  ( 2 , MyCoopNode9_I5  )
#  ( 2 , MyCoopNode10_I5 )
#  ( 2 , MyCoopNode11_I5 )
#  ( 2 , MyCoopNode12_I5 )
#  ( 3 , DepotRep_1      )
#  ( 3 , DepotRep_2      )
#  ( 3 , DepotRep_3      )
#  ( 3 , DepotRep_4      )
#  ( 3 , DepotRep_5      )
#  ( 3 , DepotRep_6      )
#  ( 3 , DepotRep_7      )
#  ( 3 , DepotRep_8      )
#  ( 3 , DepotRep_9      )
#  ( 3 , DepotRep_10     )
#  ( 3 , MyPickNode1_I1  )
#  ( 3 , MyPickNode2_I1  )
#  ( 3 , MyPickNode3_I1  )
#  ( 3 , MyPickNode4_I1  )
#  ( 3 , MyPickNode5_I1  )
#  ( 3 , MyPickNode6_I1  )
#  ( 3 , MyPickNode7_I1  )
#  ( 3 , MyPickNode8_I1  )
#  ( 3 , MyPickNode9_I1  )
#  ( 3 , MyPickNode10_I1 )
#  ( 3 , MyPickNode11_I1 )
#  ( 3 , MyPickNode12_I1 )
#  ( 3 , MyPickNode13_I1 )
#  ( 3 , MyPickNode14_I1 )
#  ( 3 , MyPickNode15_I1 )
#  ( 3 , MyPickNode16_I1 )
#  ( 3 , MyPickNode17_I1 )
#  ( 3 , MyPickNode18_I1 )
#  ( 3 , MyPickNode19_I1 )
#  ( 3 , MyPickNode20_I1 )
#  ( 3 , MyPickNode21_I1 )
#  ( 3 , MyPickNode22_I1 )
#  ( 3 , MyPickNode23_I1 )
#  ( 3 , MyPickNode24_I1 )
#  ( 3 , MyCoopNode1_I1  )
#  ( 3 , MyCoopNode2_I1  )
#  ( 3 , MyCoopNode3_I1  )
#  ( 3 , MyCoopNode4_I1  )
#  ( 3 , MyCoopNode5_I1  )
#  ( 3 , MyCoopNode6_I1  )
#  ( 3 , MyCoopNode7_I1  )
#  ( 3 , MyCoopNode8_I1  )
#  ( 3 , MyCoopNode9_I1  )
#  ( 3 , MyCoopNode10_I1 )
#  ( 3 , MyCoopNode11_I1 )
#  ( 3 , MyCoopNode12_I1 )
#  ( 3 , MyPickNode1_I2  )
#  ( 3 , MyPickNode2_I2  )
#  ( 3 , MyPickNode3_I2  )
#  ( 3 , MyPickNode4_I2  )
#  ( 3 , MyPickNode5_I2  )
#  ( 3 , MyPickNode6_I2  )
#  ( 3 , MyPickNode7_I2  )
#  ( 3 , MyPickNode8_I2  )
#  ( 3 , MyPickNode9_I2  )
#  ( 3 , MyPickNode10_I2 )
#  ( 3 , MyPickNode11_I2 )
#  ( 3 , MyPickNode12_I2 )
#  ( 3 , MyPickNode13_I2 )
#  ( 3 , MyPickNode14_I2 )
#  ( 3 , MyPickNode15_I2 )
#  ( 3 , MyPickNode16_I2 )
#  ( 3 , MyPickNode17_I2 )
#  ( 3 , MyPickNode18_I2 )
#  ( 3 , MyPickNode19_I2 )
#  ( 3 , MyPickNode20_I2 )
#  ( 3 , MyPickNode21_I2 )
#  ( 3 , MyPickNode22_I2 )
#  ( 3 , MyPickNode23_I2 )
#  ( 3 , MyPickNode24_I2 )
#  ( 3 , MyCoopNode1_I2  )
#  ( 3 , MyCoopNode2_I2  )
#  ( 3 , MyCoopNode3_I2  )
#  ( 3 , MyCoopNode4_I2  )
#  ( 3 , MyCoopNode5_I2  )
#  ( 3 , MyCoopNode6_I2  )
#  ( 3 , MyCoopNode7_I2  )
#  ( 3 , MyCoopNode8_I2  )
#  ( 3 , MyCoopNode9_I2  )
#  ( 3 , MyCoopNode10_I2 )
#  ( 3 , MyCoopNode11_I2 )
#  ( 3 , MyCoopNode12_I2 )
#  ( 3 , MyPickNode1_I3  )
#  ( 3 , MyPickNode2_I3  )
#  ( 3 , MyPickNode3_I3  )
#  ( 3 , MyPickNode4_I3  )
#  ( 3 , MyPickNode5_I3  )
#  ( 3 , MyPickNode6_I3  )
#  ( 3 , MyPickNode7_I3  )
#  ( 3 , MyPickNode8_I3  )
#  ( 3 , MyPickNode9_I3  )
#  ( 3 , MyPickNode10_I3 )
#  ( 3 , MyPickNode11_I3 )
#  ( 3 , MyPickNode12_I3 )
#  ( 3 , MyPickNode13_I3 )
#  ( 3 , MyPickNode14_I3 )
#  ( 3 , MyPickNode15_I3 )
#  ( 3 , MyPickNode16_I3 )
#  ( 3 , MyPickNode17_I3 )
#  ( 3 , MyPickNode18_I3 )
#  ( 3 , MyPickNode19_I3 )
#  ( 3 , MyPickNode20_I3 )
#  ( 3 , MyPickNode21_I3 )
#  ( 3 , MyPickNode22_I3 )
#  ( 3 , MyPickNode23_I3 )
#  ( 3 , MyPickNode24_I3 )
#  ( 3 , MyCoopNode1_I3  )
#  ( 3 , MyCoopNode2_I3  )
#  ( 3 , MyCoopNode3_I3  )
#  ( 3 , MyCoopNode4_I3  )
#  ( 3 , MyCoopNode5_I3  )
#  ( 3 , MyCoopNode6_I3  )
#  ( 3 , MyCoopNode7_I3  )
#  ( 3 , MyCoopNode8_I3  )
#  ( 3 , MyCoopNode9_I3  )
#  ( 3 , MyCoopNode10_I3 )
#  ( 3 , MyCoopNode11_I3 )
#  ( 3 , MyCoopNode12_I3 )
#  ( 3 , MyPickNode1_I4  )
#  ( 3 , MyPickNode2_I4  )
#  ( 3 , MyPickNode3_I4  )
#  ( 3 , MyPickNode4_I4  )
#  ( 3 , MyPickNode5_I4  )
#  ( 3 , MyPickNode6_I4  )
#  ( 3 , MyPickNode7_I4  )
#  ( 3 , MyPickNode8_I4  )
#  ( 3 , MyPickNode9_I4  )
#  ( 3 , MyPickNode10_I4 )
#  ( 3 , MyPickNode11_I4 )
#  ( 3 , MyPickNode12_I4 )
#  ( 3 , MyPickNode13_I4 )
#  ( 3 , MyPickNode14_I4 )
#  ( 3 , MyPickNode15_I4 )
#  ( 3 , MyPickNode16_I4 )
#  ( 3 , MyPickNode17_I4 )
#  ( 3 , MyPickNode18_I4 )
#  ( 3 , MyPickNode19_I4 )
#  ( 3 , MyPickNode20_I4 )
#  ( 3 , MyPickNode21_I4 )
#  ( 3 , MyPickNode22_I4 )
#  ( 3 , MyPickNode23_I4 )
#  ( 3 , MyPickNode24_I4 )
#  ( 3 , MyCoopNode1_I4  )
#  ( 3 , MyCoopNode2_I4  )
#  ( 3 , MyCoopNode3_I4  )
#  ( 3 , MyCoopNode4_I4  )
#  ( 3 , MyCoopNode5_I4  )
#  ( 3 , MyCoopNode6_I4  )
#  ( 3 , MyCoopNode7_I4  )
#  ( 3 , MyCoopNode8_I4  )
#  ( 3 , MyCoopNode9_I4  )
#  ( 3 , MyCoopNode10_I4 )
#  ( 3 , MyCoopNode11_I4 )
#  ( 3 , MyCoopNode12_I4 )
#  ( 3 , MyPickNode1_I5  )
#  ( 3 , MyPickNode2_I5  )
#  ( 3 , MyPickNode3_I5  )
#  ( 3 , MyPickNode4_I5  )
#  ( 3 , MyPickNode5_I5  )
#  ( 3 , MyPickNode6_I5  )
#  ( 3 , MyPickNode7_I5  )
#  ( 3 , MyPickNode8_I5  )
#  ( 3 , MyPickNode9_I5  )
#  ( 3 , MyPickNode10_I5 )
#  ( 3 , MyPickNode11_I5 )
#  ( 3 , MyPickNode12_I5 )
#  ( 3 , MyPickNode13_I5 )
#  ( 3 , MyPickNode14_I5 )
#  ( 3 , MyPickNode15_I5 )
#  ( 3 , MyPickNode16_I5 )
#  ( 3 , MyPickNode17_I5 )
#  ( 3 , MyPickNode18_I5 )
#  ( 3 , MyPickNode19_I5 )
#  ( 3 , MyPickNode20_I5 )
#  ( 3 , MyPickNode21_I5 )
#  ( 3 , MyPickNode22_I5 )
#  ( 3 , MyPickNode23_I5 )
#  ( 3 , MyPickNode24_I5 )
#  ( 3 , MyCoopNode1_I5  )
#  ( 3 , MyCoopNode2_I5  )
#  ( 3 , MyCoopNode3_I5  )
#  ( 3 , MyCoopNode4_I5  )
#  ( 3 , MyCoopNode5_I5  )
#  ( 3 , MyCoopNode6_I5  )
#  ( 3 , MyCoopNode7_I5  )
#  ( 3 , MyCoopNode8_I5  )
#  ( 3 , MyCoopNode9_I5  )
#  ( 3 , MyCoopNode10_I5 )
#  ( 3 , MyCoopNode11_I5 )
#  ( 3 , MyCoopNode12_I5 )
# >

# %% [markdown]
# ### Transporter payload at node decision variables -- S[e2,k]

# %%
# create the decision variable
St = model.addVars(Dtt, vtype=GRB.INTEGER, ub = tt_df['Capacity'].tolist(), name = 'St')

# %% [markdown]
# ### Cooperation flag decision variables -- H[i]

# %%
# new all item df
NewI = I.copy()
NewI['Cell'] = 1
# create dicts for decision variable
DH, _ = multidict(NewI.set_index(['ItemID']).to_dict()['Cell'])
# create the decision variable
H = model.addVars(DH, vtype=GRB.BINARY, name = 'Handoff')

# %% [markdown]
# ### Some useful lists and dicts for building constraints

# %%
# Picking Locations list
PLsL = RI['Node'].tolist()
# all handoff replicas list
HRsL = HRI['Node'].tolist()
# pickers list
PsL = pickers['PickerID'].tolist()
# pikcer home list
PHL = Hp['k'].tolist()
# transporter list
TsL = transporters['TransporterID'].tolist()
# transporter home list
THL = Ht['k1'].tolist()
# all items list (include virtual items)
IsL = lineItem['ItemID'].tolist()
IsL.extend([0,-1])
# all depot replicas list
DpsL = D['Reps'].tolist()
# bigM for all time related constraints
BigMtime = 10000

# %%
DpsL+HRsL
# Out:
# ['DepotRep_1',
#  'DepotRep_2',
#  'DepotRep_3',
#  'DepotRep_4',
#  'DepotRep_5',
#  'DepotRep_6',
#  'DepotRep_7',
#  'DepotRep_8',
#  'DepotRep_9',
#  'DepotRep_10',
#  'MyPickNode1_I1',
#  'MyPickNode2_I1',
#  'MyPickNode3_I1',
#  'MyPickNode4_I1',
#  'MyPickNode5_I1',
#  'MyPickNode6_I1',
#  'MyPickNode7_I1',
#  'MyPickNode8_I1',
#  'MyPickNode9_I1',
#  'MyPickNode10_I1',
#  'MyPickNode11_I1',
#  'MyPickNode12_I1',
#  'MyPickNode13_I1',
#  'MyPickNode14_I1',
#  'MyPickNode15_I1',
#  'MyPickNode16_I1',
#  'MyPickNode17_I1',
#  'MyPickNode18_I1',
#  'MyPickNode19_I1',
#  'MyPickNode20_I1',
#  'MyPickNode21_I1',
#  'MyPickNode22_I1',
#  'MyPickNode23_I1',
#  'MyPickNode24_I1',
#  'MyCoopNode1_I1',
#  'MyCoopNode2_I1',
#  'MyCoopNode3_I1',
#  'MyCoopNode4_I1',
#  'MyCoopNode5_I1',
#  'MyCoopNode6_I1',
#  'MyCoopNode7_I1',
#  'MyCoopNode8_I1',
#  'MyCoopNode9_I1',
#  'MyCoopNode10_I1',
#  'MyCoopNode11_I1',
#  'MyCoopNode12_I1',
#  'MyPickNode1_I2',
#  'MyPickNode2_I2',
#  'MyPickNode3_I2',
#  'MyPickNode4_I2',
#  'MyPickNode5_I2',
#  'MyPickNode6_I2',
#  'MyPickNode7_I2',
#  'MyPickNode8_I2',
#  'MyPickNode9_I2',
#  'MyPickNode10_I2',
#  'MyPickNode11_I2',
#  'MyPickNode12_I2',
#  'MyPickNode13_I2',
#  'MyPickNode14_I2',
#  'MyPickNode15_I2',
#  'MyPickNode16_I2',
#  'MyPickNode17_I2',
#  'MyPickNode18_I2',
#  'MyPickNode19_I2',
#  'MyPickNode20_I2',
#  'MyPickNode21_I2',
#  'MyPickNode22_I2',
#  'MyPickNode23_I2',
#  'MyPickNode24_I2',
#  'MyCoopNode1_I2',
#  'MyCoopNode2_I2',
#  'MyCoopNode3_I2',
#  'MyCoopNode4_I2',
#  'MyCoopNode5_I2',
#  'MyCoopNode6_I2',
#  'MyCoopNode7_I2',
#  'MyCoopNode8_I2',
#  'MyCoopNode9_I2',
#  'MyCoopNode10_I2',
#  'MyCoopNode11_I2',
#  'MyCoopNode12_I2',
#  'MyPickNode1_I3',
#  'MyPickNode2_I3',
#  'MyPickNode3_I3',
#  'MyPickNode4_I3',
#  'MyPickNode5_I3',
#  'MyPickNode6_I3',
#  'MyPickNode7_I3',
#  'MyPickNode8_I3',
#  'MyPickNode9_I3',
#  'MyPickNode10_I3',
#  'MyPickNode11_I3',
#  'MyPickNode12_I3',
#  'MyPickNode13_I3',
#  'MyPickNode14_I3',
#  'MyPickNode15_I3',
#  'MyPickNode16_I3',
#  'MyPickNode17_I3',
#  'MyPickNode18_I3',
#  'MyPickNode19_I3',
#  'MyPickNode20_I3',
#  'MyPickNode21_I3',
#  'MyPickNode22_I3',
#  'MyPickNode23_I3',
#  'MyPickNode24_I3',
#  'MyCoopNode1_I3',
#  'MyCoopNode2_I3',
#  'MyCoopNode3_I3',
#  'MyCoopNode4_I3',
#  'MyCoopNode5_I3',
#  'MyCoopNode6_I3',
#  'MyCoopNode7_I3',
#  'MyCoopNode8_I3',
#  'MyCoopNode9_I3',
#  'MyCoopNode10_I3',
#  'MyCoopNode11_I3',
#  'MyCoopNode12_I3',
#  'MyPickNode1_I4',
#  'MyPickNode2_I4',
#  'MyPickNode3_I4',
#  'MyPickNode4_I4',
#  'MyPickNode5_I4',
#  'MyPickNode6_I4',
#  'MyPickNode7_I4',
#  'MyPickNode8_I4',
#  'MyPickNode9_I4',
#  'MyPickNode10_I4',
#  'MyPickNode11_I4',
#  'MyPickNode12_I4',
#  'MyPickNode13_I4',
#  'MyPickNode14_I4',
#  'MyPickNode15_I4',
#  'MyPickNode16_I4',
#  'MyPickNode17_I4',
#  'MyPickNode18_I4',
#  'MyPickNode19_I4',
#  'MyPickNode20_I4',
#  'MyPickNode21_I4',
#  'MyPickNode22_I4',
#  'MyPickNode23_I4',
#  'MyPickNode24_I4',
#  'MyCoopNode1_I4',
#  'MyCoopNode2_I4',
#  'MyCoopNode3_I4',
#  'MyCoopNode4_I4',
#  'MyCoopNode5_I4',
#  'MyCoopNode6_I4',
#  'MyCoopNode7_I4',
#  'MyCoopNode8_I4',
#  'MyCoopNode9_I4',
#  'MyCoopNode10_I4',
#  'MyCoopNode11_I4',
#  'MyCoopNode12_I4',
#  'MyPickNode1_I5',
#  'MyPickNode2_I5',
#  'MyPickNode3_I5',
#  'MyPickNode4_I5',
#  'MyPickNode5_I5',
#  'MyPickNode6_I5',
#  'MyPickNode7_I5',
#  'MyPickNode8_I5',
#  'MyPickNode9_I5',
#  'MyPickNode10_I5',
#  'MyPickNode11_I5',
#  'MyPickNode12_I5',
#  'MyPickNode13_I5',
#  'MyPickNode14_I5',
#  'MyPickNode15_I5',
#  'MyPickNode16_I5',
#  'MyPickNode17_I5',
#  'MyPickNode18_I5',
#  'MyPickNode19_I5',
#  'MyPickNode20_I5',
#  'MyPickNode21_I5',
#  'MyPickNode22_I5',
#  'MyPickNode23_I5',
#  'MyPickNode24_I5',
#  'MyCoopNode1_I5',
#  'MyCoopNode2_I5',
#  'MyCoopNode3_I5',
#  'MyCoopNode4_I5',
#  'MyCoopNode5_I5',
#  'MyCoopNode6_I5',
#  'MyCoopNode7_I5',
#  'MyCoopNode8_I5',
#  'MyCoopNode9_I5',
#  'MyCoopNode10_I5',
#  'MyCoopNode11_I5',
#  'MyCoopNode12_I5']

# %% [markdown]
# ## Constraints

# %%
# constraint No.1
for e1, k in Dtp:
    model.addConstr(m >=tp[e1,k])

# %%
# constraint No.7
# each item will only be picked once
# each item
for i in range(1,NumItems+1):
    # the next item list
    jlist = IsL.copy()
    jlist.remove(i)
    jlist.remove(0)
    # add constraints
    model.addConstr(quicksum(quicksum(X[e1,i,j] for j in jlist) for e1 in PsL) == 1)

# each item
for j in range(1,NumItems+1):
    # the previous item list
    ilist = IsL.copy()
    ilist.remove(j)
    ilist.remove(-1)        
    # add constraints
    model.addConstr(quicksum(quicksum(X[e1,i,j] for i in ilist) for e1 in PsL) == 1)

# %%
# constraint No.18
# each picker will start from picking item 0 and end from picking item -1
for e1 in PsL:
    model.addConstr(quicksum(X[e1,i,-1] for i in range(1,NumItems+1)) == 1)
    model.addConstr(quicksum(X[e1,0,j] for j in range(1,NumItems+1)) == 1)

# %%
# constraint No.2a
# each picking location will only be visited by one picker
# each picking location
ConstrNo = 1
for ri in PLsL:
    # the previous possible nodes list of list
    klist = []
    # each picker
    for e1 in PsL:
        klist.append(P_HHRI_RI['k'][(P_HHRI_RI['e1'] == e1) & (P_HHRI_RI['k1'] == ri)].tolist())
    # add constraints
    name = 'C'+str(ConstrNo)+'_'+str(PLsL.index(ri))
    model.addConstr(quicksum(quicksum(Yp[e1,k,ri] for k in klist[e1-1]) for e1 in PsL) ==1, name)

# %%
# constraint No.2b
# after visiting a picking location, the picker will move to one of the handoff replicas of that item
# each picking location
for ri in PLsL:
    # each picker
    for e1 in PsL:
        # the possible next node list
        k1list = P_RI_HRI['k1'][(P_RI_HRI['e1'] == e1) & (P_RI_HRI['k'] == ri)].tolist()
    # add constraints
    model.addConstr(quicksum(quicksum(Yp[e1,ri,k1] for k1 in k1list) for e1 in PsL) ==1)

# %%
# constraint No.2c
# a picker will be back to its home node after picking all needed items
# each picker
for e1 in PsL:
    # home node for the picker
    k1 =  PHL[e1-1]
    # add constraints
    model.addConstr(quicksum(Yp[e1,k,k1] for k in HRsL) == 1)

# %%
# constraint No.2d
# a picker will start from its home node
# each picker
for e1 in PsL:
    # home node for the picker
    k = PHL[e1-1]
    # add constraints
    model.addConstr(quicksum(Yp[e1,k,k1] for k1 in PLsL) == 1)

# %%
# constraints No.3
# each handoff node
k1list = HRsL + DpsL
for k1 in k1list:
    e2klist = Y_T[Y_T['k1'] == k1][['e2','k']].values.tolist()
#     e2k2list = Y_T[Y_T['k'] == k1][['e2','k1']].values.tolist()
    # constraint 3.a
    # each handoff node and depot replica will be visited by no more than one transporter
    model.addConstr(quicksum(Yt[e2,k,k1] for e2,k in e2klist) <= 1)

# %%
# constraints No.3
# each transporter
for e2 in TsL:
    # each handoff node
    k1list = HRsL + DpsL
    for k1 in k1list:
        klist = Y_T[(Y_T['k1'] == k1) & (Y_T['e2'] == e2)]['k'].tolist()
        k2list = Y_T[(Y_T['k'] == k1) & (Y_T['e2'] == e2)]['k1'].tolist()
        # 3.b when a transporter enter a handoff node or a depot replica, constarint ensures that it will leave that node
        model.addConstr(quicksum(Yt[e2,k,k1] for k in klist) == quicksum(Yt[e2,k1,k2] for k2 in k2list))

# %%
# contraint No.3
for e2 in TsL:
    k1 = THL[e2-1]
    # constraints 3.c  a transporter will be back to its home node
    model.addConstr(quicksum(Yt[e2,k,k1] for k in DpsL) == 1)

for e2 in TsL:
    k = THL[e2-1]
    # constraint 3.d  a transporter will start from its home node
    model.addConstr(quicksum(Yt[e2,k,k1] for k1 in HRsL) == 1)

# %%
# # constraints No.3
# for k1 in DpsL:
#     e2klist = Y_T[Y_T['k1'] == k1][['e2','k']].values.tolist()
#     e2k2list = Y_T[Y_T['k'] == k1][['e2','k1']].values.tolist() 
#     # constraint 3.e
#     # each depot replica can only be visited once
#     model.addConstr(quicksum(Yt[e2,k,k1] for e2,k in e2klist) <= 1)
#     # constraint 3.f
#     # when a transporter enter a depot replica, constarint ensures that it will leave that node
#     model.addConstr(quicksum(Yt[e2,k,k1] for e2,k in e2klist) == quicksum(Yt[e2,k1,k2] for e2, k2 in e2k2list))

# %%
# constraints No.3
# each transporter
# each item
for i in range(1,NumItems+1):
    k1list = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
    expr = LinExpr()
    for e2 in TsL:
        for k1 in k1list:
            klist = Y_T[(Y_T['k1'] == k1) & (Y_T['e2'] == e2)]['k'].tolist()
            expr.add(quicksum(Yt[e2,k,k1] for k in klist))
    # 3.e ensure the relationshiop between Yt and H
    model.addConstr(expr == H[i])

# %%
# constraint No.3
BigM = 2
# each item
for i in range(1,NumItems+1):
    Ri = PLsL[i-1]
    k1list = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
    for k1 in k1list:
        for e2 in TsL:
            klist = Y_T[(Y_T['k1'] == k1) & (Y_T['e2'] == e2)]['k'].tolist()
            for e1 in PsL:
                # 3.f the assigned picker and transporter will meet at a handoff node of an item when Hi = 1
                model.addConstr(Yp[e1,Ri,k1] <= quicksum(Yt[e2,k,k1] for k in klist) + BigM*(2-H[i]-a[e1,e2,i]))
                model.addConstr(quicksum(Yt[e2,k,k1] for k in klist) <= Yp[e1,Ri,k1] + BigM*(2-H[i]-a[e1,e2,i]))

# %%
# constaint No.4
# each item can only be retrieved by one picker and be placed on one transporter
for i in range(1,NumItems+1):
    model.addConstr(quicksum(quicksum(a[e1,e2,i] for e2 in TsL) for e1 in PsL) == 1)

# %%
# constraints No.6
# set the node sequence constraint for pickers after picking an item
# each picker
for e1 in PsL:
    # each item
    for i in range(1,NumItems+1):
        Ri_star = PLsL[i-1][:PLsL[i-1].find('_')] + '_I' + str(i)
        model.addConstr(Yp[e1,PLsL[i-1], Ri_star] >= 1- H[i])

# %%
# constraint No.20
# an item can only picked by one picker 
#each item
for j in range(1,NumItems+1):
    ilist = list(range(0,NumItems+1))
    ilist.remove(j)
    llist = list(range(1,NumItems+1))
    llist.remove(j)
    llist.append(-1)
    # each picker
    for e1 in PsL:
        model.addConstr(quicksum(X[e1,i,j] for i in ilist) == quicksum(X[e1,j,l] for l in llist))

# %%
# constraint No.8
# to set appropriate node sequence of picker based on X[e1,i,j]
# each item i
for i in range(1,NumItems+1):
    # the next item
    jlist = list(range(1,NumItems+1))
    jlist.remove(i)
    kk1list = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
    # each picker
    for e1 in PsL:
        HNe1 = PHL[e1-1]
        # the next item
        for j in jlist:      
            # add constraints
            model.addConstr(2*X[e1,i,j] <= quicksum(Yp[e1,PLsL[i-1],kk1]+Yp[e1,kk1,PLsL[j-1]] for kk1 in kk1list))
            model.addConstr(X[e1,i,j]+1 >= quicksum(Yp[e1,PLsL[i-1],kk1]+Yp[e1,kk1,PLsL[j-1]] for kk1 in kk1list))
        model.addConstr(2*X[e1,i,-1] <= quicksum(Yp[e1,PLsL[i-1],kk1]+Yp[e1,kk1,HNe1] for kk1 in kk1list))
        model.addConstr(X[e1,i,-1]+1 >= quicksum(Yp[e1,PLsL[i-1],kk1]+Yp[e1,kk1,HNe1] for kk1 in kk1list))
        model.addConstr(2*X[e1,0,i] <= quicksum(Yp[e1,PLsL[i-1],kk1] for kk1 in kk1list) + Yp[e1,HNe1,PLsL[i-1]])
        model.addConstr(X[e1,0,i]+1 >= quicksum(Yp[e1,PLsL[i-1],kk1] for kk1 in kk1list) + Yp[e1,HNe1,PLsL[i-1]])

# %%
# constraint No.9
# the time picker travel from picking node to handoff node
PKT = 30
# each picker
for e1 in PsL:
    # each item
    for i in range(1,NumItems+1):
        # the handoff replicas of item i
        klist = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
        Ri = PLsL[i-1]
        # each handoff node
        for k in klist:
            model.addConstr(tp[e1,k] >= tp[e1,Ri] + PKT + Lp[Ri,k]/Vp[e1] - BigMtime*(1-Yp[e1,Ri,k]))

# %%
# constraint No.10
# the time picker travel from handoff node to picking node
# each picker
for e1 in PsL:
    # each item
    for i in range(1,NumItems+1): 
        jlist = list(range(1,NumItems+1))
        jlist.remove(i)
        Ri_star = PLsL[i-1][:PLsL[i-1].find('_')] + '_I' + str(i)
        # the handoff replicas of item i
        klist = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
        # the next item
        for j in jlist:
            Rj = PLsL[j-1]
            # 10.a when H[i] = 0
            model.addConstr(tp[e1,Rj] >= tp[e1,Ri_star] + Lp[Ri_star,Rj]/Vp[e1] - BigMtime*(1-X[e1,i,j]+H[i]))
            # each handoff node of item i
            for k in klist:
                # 10.b when H[i] = 1
                model.addConstr(tp[e1,Rj] >=tp[e1,k] + Lp[k,Rj]/Vp[e1] + PLT[e1]*Sp[e1,k] - BigMtime*(3-X[e1,i,j]-Yp[e1,k,Rj]-H[i]))

# %%
# constraint No.11
# The time picker travel from home node to picking node
# each picker
for e1 in PsL:
    HNe1 = PHL[e1-1]
    # each item
    for i in range(1,NumItems+1):
        Ri = PLsL[i-1]
        model.addConstr(tp[e1,Ri] >= Lp[HNe1,Ri]/Vp[e1] - BigMtime*(1-Yp[e1,HNe1,Ri]))
#         model.addConstr(tp[e1,Ri] <= Lp[HNe1,Ri]/Vp[e1] + BigMtime*(1-Yp[e1,HNe1,Ri]))

# %%
# constraints No.12
# the constraints about picker's payload at picking node
# each picker
for e1 in PsL:
    # each item
    for i in range(1,NumItems+1):
        jlist = list(range(1,NumItems+1))
        jlist.remove(i)
        # the next item
        for j in jlist:
            model.addConstr(Sp[e1,PLsL[j-1]] >= -Cp[e1]*(2-X[e1,i,j]-H[i]))
            model.addConstr(Sp[e1,PLsL[j-1]] <= Cp[e1]*(2-X[e1,i,j]-H[i]))            
            Ri_star = PLsL[i-1][:PLsL[i-1].find('_')] + '_I' + str(i)
            model.addConstr(Sp[e1,PLsL[j-1]] >= -Cp[e1]*(1-X[e1,i,j]+H[i]) + Sp[e1,Ri_star])
            model.addConstr(Sp[e1,PLsL[j-1]] <= Cp[e1]*(1-X[e1,i,j]+H[i]) + Sp[e1,Ri_star])

# %%
# constraints No.13
# each picker
for e1 in PsL:
    HNe1 = PHL[e1-1]
    # each item:
    for i in range(1,NumItems+1):
        Ri = PLsL[i-1]
        # 13.a the constraints ensure that each picker has zero payload when reach the its first picking node 
        model.addConstr(Sp[e1,Ri] >= -Cp[e1]*(1-Yp[e1,HNe1,Ri]))
        model.addConstr(Sp[e1,Ri] <=  Cp[e1]*(1-Yp[e1,HNe1,Ri]))
        # 13.b the constraints ensure that the payload of unrelated first picking location is zero for a picker
        elist = PsL.copy()
        elist.remove(e1)
        expr = LinExpr(1)
        for e in elist:
            HNe = PHL[e-1]
            expr.add(-Yp[e,HNe,Ri])
        model.addConstr(Sp[e1,Ri] >= -Cp[e1]*expr)
        model.addConstr(Sp[e1,Ri] <=  Cp[e1]*expr)

# %%
# constraint No.14
# the constraints about picker's payload at handoff node
# each picker
for e1 in PsL:
    # each item
    for i in range(1,NumItems+1):
        # the handoff replicas of item i
        klist = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
        for k in klist:
            model.addConstr(Sp[e1,k] >= -Cp[e1]*(1-Yp[e1,PLsL[i-1],k]) + Sp[e1,PLsL[i-1]] + 1)
            model.addConstr(Sp[e1,k] <= Cp[e1]*(1-Yp[e1,PLsL[i-1],k]) + Sp[e1,PLsL[i-1]] + 1)
            model.addConstr(Sp[e1,k] >= -Cp[e1]*(Yp[e1,PLsL[i-1],k]))
            model.addConstr(Sp[e1,k] <= Cp[e1]*(Yp[e1,PLsL[i-1],k]))

# %%
# constraint No.19
# to set appropriate node sequence of picker based on X[e1,i,j]
BigM = 2
# each item i
for i in range(1,NumItems+1):
    jlist = list(range(1,NumItems+1))
    jlist.remove(i)
    kk1list = RI_HRI['k1'][RI_HRI['ItemID'] == i].tolist()
    # each picker       
    for e1 in PsL:
        HNe1 = 'MyHome_P' + str(e1)
        # add constraints 19.b
        # each node of HRi
        for kk1 in kk1list:
            model.addConstr(Yp[e1,PLsL[i-1],kk1] <= Yp[e1,kk1,HNe1] + BigM*(1-X[e1,i,-1]))
            model.addConstr(Yp[e1,kk1,HNe1] <= Yp[e1,PLsL[i-1],kk1] + BigM*(1-X[e1,i,-1]))
        # the next item
        for j in jlist:
            # each node of HRi
            for kk1 in kk1list:
            # add constraints 19.a
                model.addConstr(Yp[e1,PLsL[i-1],kk1] <= Yp[e1,kk1,PLsL[j-1]] + BigM*(1-X[e1,i,j]))
                model.addConstr(Yp[e1,kk1,PLsL[j-1]] <= Yp[e1,PLsL[i-1],kk1] + BigM*(1-X[e1,i,j]))

# %%
obj = m
model.setObjective(obj, GRB.MINIMIZE)
# solve model
model.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10564 rows, 93276 columns and 726375 nonzeros
# Model fingerprint: 0xc7220f84
# Variable types: 941 continuous, 92335 integer (91395 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 605 rows and 1164 columns
# Presolve time: 1.03s
#
# Explored 0 nodes (0 simplex iterations) in 1.12 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
# #display solution

# print("Obj: {:.5f}".format(model.objVal))

# model.printAttr('Xn')
model.setParam('SolutionNumber', 0)
model.printAttr('Xn')
# Out:
#     Variable           Xn
# -------------------------
#            m      260.005
#     A[1,3,1]            1
#     A[2,1,2]            1
#     A[1,3,3]            1
#     A[2,1,4]            1
#     A[1,3,5]            1
#     X[1,5,4]            1
#     X[1,0,5]            1
#    X[1,4,-1]            1
#     X[2,1,2]            1
#     X[2,3,1]            1
#     X[2,0,3]            1
#    X[2,2,-1]            1
# Yp[1,MyPickNode18_PL4,MyCoopNode9_I4]            1
# Yp[1,MyPickNode18_PL5,MyPickNode18_I5]            1
# Yp[2,MyPickNode3_PL1,MyPickNode4_I1]            1
# Yp[2,MyPickNode5_PL2,MyPickNode5_I2]            1
# Yp[2,MyPickNode4_PL3,MyPickNode4_I3]            1
# Yp[1,MyPickNode18_I5,MyPickNode18_PL4]            1
# Yp[2,MyPickNode4_I3,MyPickNode3_PL1]            1
# Yp[2,MyPickNode4_I1,MyPickNode5_PL2]            1
# Yp[1,MyHome_P1,MyPickNode18_PL5]            1
# Yp[2,MyHome_P2,MyPickNode4_PL3]            1
# Yp[1,MyCoopNode9_I4,MyHome_P1]            1
# Yp[2,MyPickNode5_I2,MyHome_P2]            1
# Yt[1,MyHome_T1,MyPickNode5_I2]            1
# Yt[2,MyHome_T2,MyPickNode1_I3]            1
# Yt[3,MyHome_T3,MyPickNode5_I4]            1
# Yt[1,MyPickNode5_I2,DepotRep_1]            1
# Yt[2,MyPickNode1_I1,DepotRep_3]            1
# Yt[2,MyPickNode1_I3,DepotRep_2]            1
# Yt[3,MyPickNode18_I5,DepotRep_7]            1
# Yt[2,DepotRep_3,MyPickNode1_I1]            1
# Yt[1,DepotRep_1,MyHome_T1]            1
# Yt[2,DepotRep_2,MyHome_T2]            1
# Yt[3,DepotRep_7,MyHome_T3]            1
# Yt[3,MyPickNode5_I4,MyPickNode18_I5]            1
# tp[1,MyPickNode5_PL2]      44.9994
# tp[1,MyPickNode18_PL4]      184.999
# tp[1,MyPickNode18_PL5]      109.999
# tp[1,MyPickNode3_I1]      260.005
# tp[1,MyPickNode5_I1]      260.005
# tp[1,MyPickNode6_I1]      260.005
# tp[1,MyPickNode7_I1]      260.005
# tp[1,MyPickNode23_I1]      260.005
# tp[1,MyCoopNode3_I1]      260.005
# tp[1,MyCoopNode4_I1]      260.005
# tp[1,MyCoopNode6_I1]      260.005
# tp[1,MyCoopNode10_I1]      260.005
# tp[1,MyCoopNode12_I1]      260.005
# tp[1,MyPickNode1_I2]      260.005
# tp[1,MyPickNode4_I2]      260.005
# tp[1,MyPickNode17_I2]      260.005
# tp[1,MyPickNode20_I2]      260.005
# tp[1,MyPickNode21_I2]      260.005
# tp[1,MyPickNode22_I2]      260.005
# tp[1,MyPickNode23_I2]      260.005
# tp[1,MyPickNode24_I2]      260.005
# tp[1,MyCoopNode1_I2]      260.005
# tp[1,MyCoopNode2_I2]      260.005
# tp[1,MyCoopNode3_I2]      260.005
# tp[1,MyCoopNode4_I2]      260.005
# tp[1,MyCoopNode5_I2]      260.005
# tp[1,MyCoopNode7_I2]      260.005
# tp[1,MyCoopNode8_I2]      260.005
# tp[1,MyCoopNode11_I2]      260.005
# tp[1,MyCoopNode12_I2]      260.005
# tp[1,MyPickNode10_I4]      260.005
# tp[1,MyPickNode15_I4]      184.999
# tp[1,MyPickNode18_I4]      184.999
# tp[1,MyCoopNode9_I4]          220
# tp[1,MyCoopNode10_I4]      260.005
# tp[1,MyPickNode18_I5]      139.999
# tp[2,MyPickNode3_PL1]      125.005
# tp[2,MyPickNode5_PL2]      230.005
# tp[2,MyPickNode4_PL3]           40
# tp[2,MyPickNode1_I1]      260.005
# tp[2,MyPickNode4_I1]      165.005
# tp[2,MyPickNode5_I2]      260.005
# tp[2,MyPickNode17_I2]      260.005
# tp[2,MyPickNode18_I2]      260.005
# tp[2,MyPickNode4_I3]           70
# tp[2,MyCoopNode10_I3]      22.2484
# tp[2,MyPickNode2_I4]      260.005
# tp[2,MyPickNode6_I4]      260.005
# tp[2,MyPickNode13_I4]      260.005
# tp[2,MyPickNode17_I4]      260.005
# tp[2,MyPickNode18_I4]      260.005
# tp[2,MyCoopNode5_I4]      260.005
# tp[2,MyCoopNode9_I4]      260.005
# tp[2,MyCoopNode12_I4]      260.005
# tp[2,MyPickNode16_I5]      260.005
# tp[2,MyPickNode18_I5]      260.005
# Sp[1,MyCoopNode9_I4]            1
# Sp[1,MyPickNode18_I5]            1
# Sp[2,MyPickNode18_PL4]            2
# Sp[2,MyPickNode4_I1]            1
# Sp[2,MyPickNode5_I2]            1
# Sp[2,MyPickNode4_I3]            1
#   Handoff[1]            1
#   Handoff[2]            1
#   Handoff[3]            1
#   Handoff[4]            1
#   Handoff[5]            1

# %%
count = 0
for v in model.getVars():
    if 'Handoff' in v.VarName and v.x==1:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(keys)
print(count)
# Out:
# ['1']
# ['2']
# ['3']
# ['4']
# ['5']
# 5

# %%
count = 0
for v in model.getVars():
    if 'X' in v.VarName and v.x==1:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(keys)
print(count)
# Out:
# ['1', '5', '4']
# ['1', '0', '5']
# ['1', '4', '-1']
# ['2', '1', '2']
# ['2', '3', '1']
# ['2', '0', '3']
# ['2', '2', '-1']
# 7

# %%
count = 0
for v in model.getVars():
    if 'Yp' in v.VarName and v.x==1:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(keys)
print(count)
# Out:
# ['1', 'MyPickNode18_PL4', 'MyCoopNode9_I4']
# ['1', 'MyPickNode18_PL5', 'MyPickNode18_I5']
# ['2', 'MyPickNode3_PL1', 'MyPickNode4_I1']
# ['2', 'MyPickNode5_PL2', 'MyPickNode5_I2']
# ['2', 'MyPickNode4_PL3', 'MyPickNode4_I3']
# ['1', 'MyPickNode18_I5', 'MyPickNode18_PL4']
# ['2', 'MyPickNode4_I3', 'MyPickNode3_PL1']
# ['2', 'MyPickNode4_I1', 'MyPickNode5_PL2']
# ['1', 'MyHome_P1', 'MyPickNode18_PL5']
# ['2', 'MyHome_P2', 'MyPickNode4_PL3']
# ['1', 'MyCoopNode9_I4', 'MyHome_P1']
# ['2', 'MyPickNode5_I2', 'MyHome_P2']
# 12

# %%
count = 0
for v in model.getVars():
    if 'Yt' in v.VarName and v.x==1:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(keys)
print(count)
# Out:
# ['1', 'MyHome_T1', 'MyPickNode5_I2']
# ['2', 'MyHome_T2', 'MyPickNode1_I3']
# ['3', 'MyHome_T3', 'MyPickNode5_I4']
# ['1', 'MyPickNode5_I2', 'DepotRep_1']
# ['2', 'MyPickNode1_I1', 'DepotRep_3']
# ['2', 'MyPickNode1_I3', 'DepotRep_2']
# ['3', 'MyPickNode18_I5', 'DepotRep_7']
# ['2', 'DepotRep_3', 'MyPickNode1_I1']
# ['1', 'DepotRep_1', 'MyHome_T1']
# ['2', 'DepotRep_2', 'MyHome_T2']
# ['3', 'DepotRep_7', 'MyHome_T3']
# ['3', 'MyPickNode5_I4', 'MyPickNode18_I5']
# 12

# %%
count = 0
for v in model.getVars():
    if 'Sp' in v.VarName and v.x>0:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(f'{keys}, {v.x}')
print(count)
# Out:
# ['1', 'MyCoopNode11_I1'], 1.0
# ['1', 'MyPickNode22_I2'], 1.0
# ['1', 'MyPickNode22_I3'], 1.0
# ['1', 'MyPickNode15_I6'], 1.0
# ['1', 'MyPickNode13_I7'], 1.0
# ['1', 'MyCoopNode11_I11'], 1.0
# ['1', 'MyPickNode13_I12'], 1.0
# ['1', 'MyPickNode14_I16'], 1.0
# ['2', 'MyPickNode8_I4'], 1.0
# ['2', 'MyPickNode8_I5'], 1.0
# ['2', 'MyPickNode12_I8'], 1.0
# ['2', 'MyPickNode12_I9'], 1.0
# ['2', 'MyPickNode15_I10'], 1.0
# ['2', 'MyPickNode12_I13'], 1.0
# ['2', 'MyPickNode12_I14'], 1.0
# ['2', 'MyPickNode3_I15'], 1.0
# 16

# %%
count = 0
for v in model.getVars():
    if 'tp' in v.VarName and v.x>0:
        keys = v.varName[v.varName.index('[')+1:v.varName.index(']')].split(',')
        count= count +1
        print(f'{keys}, {v.x}')
print(count)
# Out:
# ['1', 'MyPickNode22_PL1'], 710.0292512786273
# ['1', 'MyPickNode22_PL2'], 560.0292512786277
# ['1', 'MyPickNode22_PL3'], 635.0292512786277
# ['1', 'MyPickNode13_PL6'], 325.0099024020567
# ['1', 'MyPickNode13_PL7'], 175.0099024020567
# ['1', 'MyPickNode15_PL11'], 430.0083846122691
# ['1', 'MyPickNode13_PL12'], 250.0099024020567
# ['1', 'MyPickNode12_PL13'], 745.0297603779636
# ['1', 'MyPickNode3_PL16'], 30.009904136997648
# ['1', 'MyCoopNode11_I1'], 745.0297603779636
# ['1', 'MyPickNode22_I2'], 590.0292512786277
# ['1', 'MyPickNode22_I3'], 665.0292512786277
# ['1', 'MyPickNode1_I5'], 745.0297603779636
# ['1', 'MyPickNode2_I5'], 745.0297603779636
# ['1', 'MyPickNode3_I5'], 745.0297603779636
# ['1', 'MyPickNode4_I5'], 745.0297603779636
# ['1', 'MyPickNode5_I5'], 745.0297603779636
# ['1', 'MyPickNode8_I5'], 745.0297603779636
# ['1', 'MyPickNode9_I5'], 745.0297603779636
# ['1', 'MyPickNode11_I5'], 745.0297603779636
# ['1', 'MyPickNode13_I5'], 745.0297603779636
# ['1', 'MyPickNode15_I5'], 745.0297603779636
# ['1', 'MyPickNode16_I5'], 745.0297603779636
# ['1', 'MyPickNode17_I5'], 745.0297603779636
# ['1', 'MyPickNode18_I5'], 745.0297603779636
# ['1', 'MyPickNode19_I5'], 745.0297603779636
# ['1', 'MyPickNode22_I5'], 745.0297603779636
# ['1', 'MyPickNode23_I5'], 745.0297603779636
# ['1', 'MyPickNode24_I5'], 745.0297603779636
# ['1', 'MyCoopNode1_I5'], 745.0297603779636
# ['1', 'MyCoopNode2_I5'], 745.0297603779636
# ['1', 'MyCoopNode4_I5'], 745.0297603779636
# ['1', 'MyCoopNode5_I5'], 745.0297603779636
# ['1', 'MyCoopNode6_I5'], 745.0297603779636
# ['1', 'MyCoopNode7_I5'], 745.0297603779636
# ['1', 'MyCoopNode8_I5'], 745.0297603779636
# ['1', 'MyCoopNode9_I5'], 745.0297603779636
# ['1', 'MyCoopNode12_I5'], 745.0297603779636
# ['1', 'MyPickNode15_I6'], 385.0083846122691
# ['1', 'MyPickNode13_I7'], 205.0099024020567
# ['1', 'MyCoopNode7_I7'], 4.9968396367038395
# ['1', 'MyPickNode1_I10'], 745.0297603779636
# ['1', 'MyPickNode3_I10'], 745.0297603779636
# ['1', 'MyPickNode4_I10'], 745.0297603779636
# ['1', 'MyPickNode5_I10'], 745.0297603779636
# ['1', 'MyPickNode6_I10'], 745.0297603779636
# ['1', 'MyPickNode7_I10'], 745.0297603779636
# ['1', 'MyPickNode8_I10'], 745.0297603779636
# ['1', 'MyPickNode10_I10'], 745.0297603779636
# ['1', 'MyPickNode11_I10'], 745.0297603779636
# ['1', 'MyPickNode12_I10'], 745.0297603779636
# ['1', 'MyPickNode13_I10'], 745.0297603779636
# ['1', 'MyPickNode14_I10'], 745.0297603779636
# ['1', 'MyPickNode15_I10'], 745.0297603779636
# ['1', 'MyPickNode18_I10'], 745.0297603779636
# ['1', 'MyPickNode19_I10'], 745.0297603779636
# ['1', 'MyPickNode20_I10'], 745.0297603779636
# ['1', 'MyPickNode22_I10'], 745.0297603779636
# ['1', 'MyCoopNode1_I10'], 745.0297603779636
# ['1', 'MyCoopNode2_I10'], 745.0297603779636
# ['1', 'MyCoopNode3_I10'], 745.0297603779636
# ['1', 'MyCoopNode4_I10'], 745.0297603779636
# ['1', 'MyCoopNode6_I10'], 745.0297603779636
# ['1', 'MyCoopNode7_I10'], 745.0297603779636
# ['1', 'MyCoopNode8_I10'], 745.0297603779636
# ['1', 'MyCoopNode10_I10'], 745.0297603779636
# ['1', 'MyCoopNode12_I10'], 745.0297603779636
# ['1', 'MyPickNode3_I11'], 110.00788834213404
# ['1', 'MyPickNode4_I11'], 120.00796067062424
# ['1', 'MyPickNode6_I11'], 110.0078776681296
# ['1', 'MyPickNode7_I11'], 120.00793327251108
# ['1', 'MyPickNode9_I11'], 130.00791623454666
# ['1', 'MyPickNode12_I11'], 130.00786638876548
# ['1', 'MyPickNode14_I11'], 150.00787711667022
# ['1', 'MyPickNode15_I11'], 154.9998236208878
# ['1', 'MyPickNode16_I11'], 470.0235084679409
# ['1', 'MyPickNode17_I11'], 160.0078619675444
# ['1', 'MyPickNode20_I11'], 170.0060093825416
# ['1', 'MyPickNode23_I11'], 180.0077280739754
# ['1', 'MyPickNode24_I11'], 170.00772450118916
# ['1', 'MyCoopNode1_I11'], 105.00848674110262
# ['1', 'MyCoopNode2_I11'], 115.01060366537081
# ['1', 'MyCoopNode3_I11'], 115.00873999809505
# ['1', 'MyCoopNode4_I11'], 125.00785075430417
# ['1', 'MyCoopNode6_I11'], 135.0078684722505
# ['1', 'MyCoopNode8_I11'], 159.99986479675442
# ['1', 'MyCoopNode11_I11'], 505.01097700278865
# ['1', 'MyCoopNode12_I11'], 175.00785196374295
# ['1', 'MyPickNode13_I12'], 280.0099024020567
# ['1', 'MyPickNode14_I16'], 120.00984467624119
# ['2', 'MyPickNode22_PL1'], 30.009904136997307
# ['2', 'MyPickNode22_PL2'], 154.99806450679762
# ['2', 'MyPickNode22_PL3'], 745.0297603779636
# ['2', 'MyPickNode8_PL4'], 280.0449138926506
# ['2', 'MyPickNode8_PL5'], 355.0449138926506
# ['2', 'MyPickNode13_PL6'], 745.0297603779636
# ['2', 'MyPickNode12_PL8'], 565.0297603779636
# ['2', 'MyPickNode12_PL9'], 490.0297603779636
# ['2', 'MyPickNode15_PL10'], 165.00989208347164
# ['2', 'MyPickNode15_PL11'], 745.0297603779636
# ['2', 'MyPickNode13_PL12'], 745.0297603779636
# ['2', 'MyPickNode12_PL13'], 715.0297603779636
# ['2', 'MyPickNode12_PL14'], 640.0297603779636
# ['2', 'MyPickNode3_PL15'], 30.009904136997648
# ['2', 'MyPickNode1_I2'], 745.0297603779636
# ['2', 'MyPickNode2_I2'], 745.0297603779636
# ['2', 'MyPickNode3_I2'], 745.0297603779636
# ['2', 'MyPickNode4_I2'], 745.0297603779636
# ['2', 'MyPickNode7_I2'], 745.0297603779636
# ['2', 'MyPickNode8_I2'], 745.0297603779636
# ['2', 'MyPickNode10_I2'], 745.0297603779636
# ['2', 'MyPickNode12_I2'], 745.0297603779636
# ['2', 'MyPickNode14_I2'], 745.0297603779636
# ['2', 'MyPickNode15_I2'], 745.0297603779636
# ['2', 'MyPickNode17_I2'], 745.0297603779636
# ['2', 'MyPickNode19_I2'], 745.0297603779636
# ['2', 'MyPickNode21_I2'], 745.0297603779636
# ['2', 'MyPickNode22_I2'], 745.0297603779636
# ['2', 'MyPickNode24_I2'], 745.0297603779636
# ['2', 'MyCoopNode1_I2'], 745.0297603779636
# ['2', 'MyCoopNode2_I2'], 745.0297603779636
# ['2', 'MyCoopNode4_I2'], 745.0297603779636
# ['2', 'MyCoopNode5_I2'], 745.0297603779636
# ['2', 'MyCoopNode7_I2'], 745.0297603779636
# ['2', 'MyCoopNode8_I2'], 745.0297603779636
# ['2', 'MyCoopNode9_I2'], 745.0297603779636
# ['2', 'MyCoopNode10_I2'], 745.0297603779636
# ['2', 'MyCoopNode11_I2'], 745.0297603779636
# ['2', 'MyCoopNode12_I2'], 745.0297603779636
# ['2', 'MyPickNode7_I4'], 19.99774999974636
# ['2', 'MyPickNode8_I4'], 310.0449138926506
# ['2', 'MyPickNode9_I4'], 9.99999710265422
# ['2', 'MyCoopNode4_I4'], 24.84096053626729
# ['2', 'MyCoopNode5_I4'], 4.999591654398159
# ['2', 'MyPickNode1_I5'], 45.001235056781866
# ['2', 'MyPickNode3_I5'], 75.00015326228151
# ['2', 'MyPickNode4_I5'], 84.92298664431712
# ['2', 'MyPickNode5_I5'], 85.00036264024368
# ['2', 'MyPickNode7_I5'], 65.00036504724687
# ['2', 'MyPickNode8_I5'], 385.0449138926506
# ['2', 'MyPickNode9_I5'], 745.0297603779636
# ['2', 'MyPickNode10_I5'], 105.00031035579434
# ['2', 'MyPickNode11_I5'], 124.99554874305306
# ['2', 'MyPickNode12_I5'], 745.0297603779636
# ['2', 'MyPickNode13_I5'], 45.05096553696478
# ['2', 'MyPickNode15_I5'], 75.00036994612003
# ['2', 'MyPickNode17_I5'], 85.00003731925665
# ['2', 'MyPickNode18_I5'], 94.99485226045056
# ['2', 'MyPickNode19_I5'], 25.000366801858604
# ['2', 'MyPickNode21_I5'], 55.00032386008809
# ['2', 'MyPickNode22_I5'], 65.00069173006034
# ['2', 'MyPickNode23_I5'], 65.00059390486842
# ['2', 'MyPickNode24_I5'], 74.99947942862912
# ['2', 'MyCoopNode2_I5'], 79.99960941844313
# ['2', 'MyCoopNode3_I5'], 89.98831002541976
# ['2', 'MyCoopNode5_I5'], 100.00033561058503
# ['2', 'MyCoopNode6_I5'], 745.0297603779636
# ['2', 'MyCoopNode7_I5'], 50.00637536623674
# ['2', 'MyCoopNode8_I5'], 80.0003822463301
# ['2', 'MyCoopNode10_I5'], 30.00101757317009
# ['2', 'MyCoopNode11_I5'], 60.00407149165096
# ['2', 'MyCoopNode12_I5'], 70.00022286839942
# ['2', 'MyPickNode1_I7'], 745.0297603779636
# ['2', 'MyPickNode2_I7'], 745.0297603779636
# ['2', 'MyPickNode3_I7'], 745.0297603779636
# ['2', 'MyPickNode4_I7'], 745.0297603779636
# ['2', 'MyPickNode5_I7'], 745.0297603779636
# ['2', 'MyPickNode6_I7'], 745.0297603779636
# ['2', 'MyPickNode7_I7'], 745.0297603779636
# ['2', 'MyPickNode8_I7'], 745.0297603779636
# ['2', 'MyPickNode9_I7'], 745.0297603779636
# ['2', 'MyPickNode10_I7'], 745.0297603779636
# ['2', 'MyPickNode11_I7'], 745.0297603779636
# ['2', 'MyPickNode12_I7'], 745.0297603779636
# ['2', 'MyPickNode13_I7'], 745.0297603779636
# ['2', 'MyPickNode14_I7'], 745.0297603779636
# ['2', 'MyPickNode16_I7'], 745.0297603779636
# ['2', 'MyPickNode18_I7'], 745.0297603779636
# ['2', 'MyPickNode22_I7'], 745.0297603779636
# ['2', 'MyPickNode23_I7'], 745.0297603779636
# ['2', 'MyPickNode24_I7'], 745.0297603779636
# ['2', 'MyCoopNode1_I7'], 745.0297603779636
# ['2', 'MyCoopNode2_I7'], 745.0297603779636
# ['2', 'MyCoopNode3_I7'], 745.0297603779636
# ['2', 'MyCoopNode5_I7'], 745.0297603779636
# ['2', 'MyCoopNode6_I7'], 745.0297603779636
# ['2', 'MyCoopNode7_I7'], 745.0297603779636
# ['2', 'MyCoopNode8_I7'], 745.0297603779636
# ['2', 'MyCoopNode9_I7'], 745.0297603779636
# ['2', 'MyCoopNode10_I7'], 745.0297603779636
# ['2', 'MyCoopNode11_I7'], 745.0297603779636
# ['2', 'MyCoopNode12_I7'], 745.0297603779636
# ['2', 'MyPickNode12_I8'], 595.0297603779636
# ['2', 'MyPickNode12_I9'], 520.0297603779636
# ['2', 'MyPickNode1_I10'], 19.999887257581417
# ['2', 'MyPickNode3_I10'], 29.999999459599962
# ['2', 'MyPickNode4_I10'], 19.999999733990876
# ['2', 'MyPickNode7_I10'], 59.997749854926845
# ['2', 'MyPickNode9_I10'], 49.999996957834696
# ['2', 'MyPickNode10_I10'], 39.999705095891386
# ['2', 'MyPickNode11_I10'], 19.99049801577337
# ['2', 'MyPickNode12_I10'], 9.99979522603087
# ['2', 'MyPickNode13_I10'], 20.000011387281006
# ['2', 'MyPickNode15_I10'], 195.00989208347164
# ['2', 'MyPickNode16_I10'], 20.000013819895486
# ['2', 'MyPickNode17_I10'], 745.0297603779636
# ['2', 'MyPickNode20_I10'], 10.000016640522404
# ['2', 'MyCoopNode1_I10'], 24.99878924270149
# ['2', 'MyCoopNode2_I10'], 24.996365780592782
# ['2', 'MyCoopNode4_I10'], 64.84096039144777
# ['2', 'MyCoopNode5_I10'], 44.99959150957858
# ['2', 'MyCoopNode7_I10'], 24.999702051863892
# ['2', 'MyCoopNode8_I10'], 24.999902656185327
# ['2', 'MyCoopNode11_I10'], 4.999999855062811
# ['2', 'MyPickNode12_I13'], 745.0297603779636
# ['2', 'MyPickNode4_I14'], 745.0297603779636
# ['2', 'MyPickNode9_I14'], 745.0297603779636
# ['2', 'MyPickNode12_I14'], 670.0297603779636
# ['2', 'MyPickNode3_I15'], 60.00990413699765
# 219

# %%
model.getVars()
# Out:
# [<gurobi.Var m (value 745.0297603779636)>,
#  <gurobi.Var A[1,1,1] (value 1.0)>,
#  <gurobi.Var A[1,2,1] (value 0.0)>,
#  <gurobi.Var A[1,3,1] (value 0.0)>,
#  <gurobi.Var A[2,1,1] (value 0.0)>,
#  <gurobi.Var A[2,2,1] (value 0.0)>,
#  <gurobi.Var A[2,3,1] (value 0.0)>,
#  <gurobi.Var A[1,1,2] (value 1.0)>,
#  <gurobi.Var A[1,2,2] (value 0.0)>,
#  <gurobi.Var A[1,3,2] (value 0.0)>,
#  <gurobi.Var A[2,1,2] (value 0.0)>,
#  <gurobi.Var A[2,2,2] (value 0.0)>,
#  <gurobi.Var A[2,3,2] (value 0.0)>,
#  <gurobi.Var A[1,1,3] (value 1.0)>,
#  <gurobi.Var A[1,2,3] (value 0.0)>,
#  <gurobi.Var A[1,3,3] (value 0.0)>,
#  <gurobi.Var A[2,1,3] (value 0.0)>,
#  <gurobi.Var A[2,2,3] (value 0.0)>,
#  <gurobi.Var A[2,3,3] (value 0.0)>,
#  <gurobi.Var A[1,1,4] (value 1.0)>,
#  <gurobi.Var A[1,2,4] (value 0.0)>,
#  <gurobi.Var A[1,3,4] (value 0.0)>,
#  <gurobi.Var A[2,1,4] (value 0.0)>,
#  <gurobi.Var A[2,2,4] (value 0.0)>,
#  <gurobi.Var A[2,3,4] (value 0.0)>,
#  <gurobi.Var A[1,1,5] (value 1.0)>,
#  <gurobi.Var A[1,2,5] (value 0.0)>,
#  <gurobi.Var A[1,3,5] (value 0.0)>,
#  <gurobi.Var A[2,1,5] (value 0.0)>,
#  <gurobi.Var A[2,2,5] (value 0.0)>,
#  <gurobi.Var A[2,3,5] (value 0.0)>,
#  <gurobi.Var A[1,1,6] (value 1.0)>,
#  <gurobi.Var A[1,2,6] (value 0.0)>,
#  <gurobi.Var A[1,3,6] (value 0.0)>,
#  <gurobi.Var A[2,1,6] (value 0.0)>,
#  <gurobi.Var A[2,2,6] (value 0.0)>,
#  <gurobi.Var A[2,3,6] (value 0.0)>,
#  <gurobi.Var A[1,1,7] (value 1.0)>,
#  <gurobi.Var A[1,2,7] (value 0.0)>,
#  <gurobi.Var A[1,3,7] (value 0.0)>,
#  <gurobi.Var A[2,1,7] (value 0.0)>,
#  <gurobi.Var A[2,2,7] (value 0.0)>,
#  <gurobi.Var A[2,3,7] (value 0.0)>,
#  <gurobi.Var A[1,1,8] (value 1.0)>,
#  <gurobi.Var A[1,2,8] (value 0.0)>,
#  <gurobi.Var A[1,3,8] (value 0.0)>,
#  <gurobi.Var A[2,1,8] (value 0.0)>,
#  <gurobi.Var A[2,2,8] (value 0.0)>,
#  <gurobi.Var A[2,3,8] (value 0.0)>,
#  <gurobi.Var A[1,1,9] (value 1.0)>,
#  <gurobi.Var A[1,2,9] (value 0.0)>,
#  <gurobi.Var A[1,3,9] (value 0.0)>,
#  <gurobi.Var A[2,1,9] (value 0.0)>,
#  <gurobi.Var A[2,2,9] (value 0.0)>,
#  <gurobi.Var A[2,3,9] (value 0.0)>,
#  <gurobi.Var A[1,1,10] (value 1.0)>,
#  <gurobi.Var A[1,2,10] (value 0.0)>,
#  <gurobi.Var A[1,3,10] (value 0.0)>,
#  <gurobi.Var A[2,1,10] (value 0.0)>,
#  <gurobi.Var A[2,2,10] (value 0.0)>,
#  <gurobi.Var A[2,3,10] (value 0.0)>,
#  <gurobi.Var A[1,1,11] (value 1.0)>,
#  <gurobi.Var A[1,2,11] (value 0.0)>,
#  <gurobi.Var A[1,3,11] (value 0.0)>,
#  <gurobi.Var A[2,1,11] (value 0.0)>,
#  <gurobi.Var A[2,2,11] (value 0.0)>,
#  <gurobi.Var A[2,3,11] (value 0.0)>,
#  <gurobi.Var A[1,1,12] (value 1.0)>,
#  <gurobi.Var A[1,2,12] (value 0.0)>,
#  <gurobi.Var A[1,3,12] (value 0.0)>,
#  <gurobi.Var A[2,1,12] (value 0.0)>,
#  <gurobi.Var A[2,2,12] (value 0.0)>,
#  <gurobi.Var A[2,3,12] (value 0.0)>,
#  <gurobi.Var A[1,1,13] (value 1.0)>,
#  <gurobi.Var A[1,2,13] (value 0.0)>,
#  <gurobi.Var A[1,3,13] (value 0.0)>,
#  <gurobi.Var A[2,1,13] (value 0.0)>,
#  <gurobi.Var A[2,2,13] (value 0.0)>,
#  <gurobi.Var A[2,3,13] (value 0.0)>,
#  <gurobi.Var A[1,1,14] (value 1.0)>,
#  <gurobi.Var A[1,2,14] (value 0.0)>,
#  <gurobi.Var A[1,3,14] (value 0.0)>,
#  <gurobi.Var A[2,1,14] (value 0.0)>,
#  <gurobi.Var A[2,2,14] (value 0.0)>,
#  <gurobi.Var A[2,3,14] (value 0.0)>,
#  <gurobi.Var A[1,1,15] (value 1.0)>,
#  <gurobi.Var A[1,2,15] (value 0.0)>,
#  <gurobi.Var A[1,3,15] (value 0.0)>,
#  <gurobi.Var A[2,1,15] (value 0.0)>,
#  <gurobi.Var A[2,2,15] (value 0.0)>,
#  <gurobi.Var A[2,3,15] (value 0.0)>,
#  <gurobi.Var A[1,1,16] (value 1.0)>,
#  <gurobi.Var A[1,2,16] (value 0.0)>,
#  <gurobi.Var A[1,3,16] (value 0.0)>,
#  <gurobi.Var A[2,1,16] (value 0.0)>,
#  <gurobi.Var A[2,2,16] (value 0.0)>,
#  <gurobi.Var A[2,3,16] (value 0.0)>,
#  <gurobi.Var X[1,1,2] (value -0.0)>,
#  <gurobi.Var X[1,1,3] (value -0.0)>,
#  <gurobi.Var X[1,1,4] (value -0.0)>,
#  <gurobi.Var X[1,1,5] (value -0.0)>,
#  <gurobi.Var X[1,1,6] (value 0.0)>,
#  <gurobi.Var X[1,1,7] (value -0.0)>,
#  <gurobi.Var X[1,1,8] (value -0.0)>,
#  <gurobi.Var X[1,1,9] (value -0.0)>,
#  <gurobi.Var X[1,1,10] (value -0.0)>,
#  <gurobi.Var X[1,1,11] (value -0.0)>,
#  <gurobi.Var X[1,1,12] (value -0.0)>,
#  <gurobi.Var X[1,1,13] (value 0.0)>,
#  <gurobi.Var X[1,1,14] (value -0.0)>,
#  <gurobi.Var X[1,1,15] (value -0.0)>,
#  <gurobi.Var X[1,1,16] (value -0.0)>,
#  <gurobi.Var X[1,2,1] (value -0.0)>,
#  <gurobi.Var X[1,2,3] (value 1.0)>,
#  <gurobi.Var X[1,2,4] (value -0.0)>,
#  <gurobi.Var X[1,2,5] (value -0.0)>,
#  <gurobi.Var X[1,2,6] (value -0.0)>,
#  <gurobi.Var X[1,2,7] (value -0.0)>,
#  <gurobi.Var X[1,2,8] (value -0.0)>,
#  <gurobi.Var X[1,2,9] (value -0.0)>,
#  <gurobi.Var X[1,2,10] (value -0.0)>,
#  <gurobi.Var X[1,2,11] (value -0.0)>,
#  <gurobi.Var X[1,2,12] (value -0.0)>,
#  <gurobi.Var X[1,2,13] (value 0.0)>,
#  <gurobi.Var X[1,2,14] (value -0.0)>,
#  <gurobi.Var X[1,2,15] (value -0.0)>,
#  <gurobi.Var X[1,2,16] (value -0.0)>,
#  <gurobi.Var X[1,3,1] (value 1.0)>,
#  <gurobi.Var X[1,3,2] (value -0.0)>,
#  <gurobi.Var X[1,3,4] (value -0.0)>,
#  <gurobi.Var X[1,3,5] (value -0.0)>,
#  <gurobi.Var X[1,3,6] (value -0.0)>,
#  <gurobi.Var X[1,3,7] (value -0.0)>,
#  <gurobi.Var X[1,3,8] (value -0.0)>,
#  <gurobi.Var X[1,3,9] (value -0.0)>,
#  <gurobi.Var X[1,3,10] (value -0.0)>,
#  <gurobi.Var X[1,3,11] (value -0.0)>,
#  <gurobi.Var X[1,3,12] (value -0.0)>,
#  <gurobi.Var X[1,3,13] (value 0.0)>,
#  <gurobi.Var X[1,3,14] (value -0.0)>,
#  <gurobi.Var X[1,3,15] (value -0.0)>,
#  <gurobi.Var X[1,3,16] (value -0.0)>,
#  <gurobi.Var X[1,4,1] (value -0.0)>,
#  <gurobi.Var X[1,4,2] (value -0.0)>,
#  <gurobi.Var X[1,4,3] (value -0.0)>,
#  <gurobi.Var X[1,4,5] (value -0.0)>,
#  <gurobi.Var X[1,4,6] (value -0.0)>,
#  <gurobi.Var X[1,4,7] (value -0.0)>,
#  <gurobi.Var X[1,4,8] (value -0.0)>,
#  <gurobi.Var X[1,4,9] (value -0.0)>,
#  <gurobi.Var X[1,4,10] (value -0.0)>,
#  <gurobi.Var X[1,4,11] (value -0.0)>,
#  <gurobi.Var X[1,4,12] (value -0.0)>,
#  <gurobi.Var X[1,4,13] (value -0.0)>,
#  <gurobi.Var X[1,4,14] (value -0.0)>,
#  <gurobi.Var X[1,4,15] (value -0.0)>,
#  <gurobi.Var X[1,4,16] (value -0.0)>,
#  <gurobi.Var X[1,5,1] (value -0.0)>,
#  <gurobi.Var X[1,5,2] (value -0.0)>,
#  <gurobi.Var X[1,5,3] (value -0.0)>,
#  <gurobi.Var X[1,5,4] (value -0.0)>,
#  <gurobi.Var X[1,5,6] (value -0.0)>,
#  <gurobi.Var X[1,5,7] (value -0.0)>,
#  <gurobi.Var X[1,5,8] (value -0.0)>,
#  <gurobi.Var X[1,5,9] (value -0.0)>,
#  <gurobi.Var X[1,5,10] (value -0.0)>,
#  <gurobi.Var X[1,5,11] (value -0.0)>,
#  <gurobi.Var X[1,5,12] (value -0.0)>,
#  <gurobi.Var X[1,5,13] (value -0.0)>,
#  <gurobi.Var X[1,5,14] (value -0.0)>,
#  <gurobi.Var X[1,5,15] (value -0.0)>,
#  <gurobi.Var X[1,5,16] (value -0.0)>,
#  <gurobi.Var X[1,6,1] (value -0.0)>,
#  <gurobi.Var X[1,6,2] (value -0.0)>,
#  <gurobi.Var X[1,6,3] (value -0.0)>,
#  <gurobi.Var X[1,6,4] (value -0.0)>,
#  <gurobi.Var X[1,6,5] (value -0.0)>,
#  <gurobi.Var X[1,6,7] (value -0.0)>,
#  <gurobi.Var X[1,6,8] (value -0.0)>,
#  <gurobi.Var X[1,6,9] (value -0.0)>,
#  <gurobi.Var X[1,6,10] (value -0.0)>,
#  <gurobi.Var X[1,6,11] (value 1.0)>,
#  <gurobi.Var X[1,6,12] (value -0.0)>,
#  <gurobi.Var X[1,6,13] (value -0.0)>,
#  <gurobi.Var X[1,6,14] (value -0.0)>,
#  <gurobi.Var X[1,6,15] (value -0.0)>,
#  <gurobi.Var X[1,6,16] (value -0.0)>,
#  <gurobi.Var X[1,7,1] (value -0.0)>,
#  <gurobi.Var X[1,7,2] (value -0.0)>,
#  <gurobi.Var X[1,7,3] (value -0.0)>,
#  <gurobi.Var X[1,7,4] (value -0.0)>,
#  <gurobi.Var X[1,7,5] (value -0.0)>,
#  <gurobi.Var X[1,7,6] (value -0.0)>,
#  <gurobi.Var X[1,7,8] (value -0.0)>,
#  <gurobi.Var X[1,7,9] (value -0.0)>,
#  <gurobi.Var X[1,7,10] (value -0.0)>,
#  <gurobi.Var X[1,7,11] (value -0.0)>,
#  <gurobi.Var X[1,7,12] (value 1.0)>,
#  <gurobi.Var X[1,7,13] (value -0.0)>,
#  <gurobi.Var X[1,7,14] (value -0.0)>,
#  <gurobi.Var X[1,7,15] (value -0.0)>,
#  <gurobi.Var X[1,7,16] (value -0.0)>,
#  <gurobi.Var X[1,8,1] (value -0.0)>,
#  <gurobi.Var X[1,8,2] (value -0.0)>,
#  <gurobi.Var X[1,8,3] (value -0.0)>,
#  <gurobi.Var X[1,8,4] (value -0.0)>,
#  <gurobi.Var X[1,8,5] (value -0.0)>,
#  <gurobi.Var X[1,8,6] (value -0.0)>,
#  <gurobi.Var X[1,8,7] (value -0.0)>,
#  <gurobi.Var X[1,8,9] (value -0.0)>,
#  <gurobi.Var X[1,8,10] (value -0.0)>,
#  <gurobi.Var X[1,8,11] (value -0.0)>,
#  <gurobi.Var X[1,8,12] (value -0.0)>,
#  <gurobi.Var X[1,8,13] (value -0.0)>,
#  <gurobi.Var X[1,8,14] (value -0.0)>,
#  <gurobi.Var X[1,8,15] (value -0.0)>,
#  <gurobi.Var X[1,8,16] (value -0.0)>,
#  <gurobi.Var X[1,9,1] (value -0.0)>,
#  <gurobi.Var X[1,9,2] (value -0.0)>,
#  <gurobi.Var X[1,9,3] (value -0.0)>,
#  <gurobi.Var X[1,9,4] (value -0.0)>,
#  <gurobi.Var X[1,9,5] (value -0.0)>,
#  <gurobi.Var X[1,9,6] (value -0.0)>,
#  <gurobi.Var X[1,9,7] (value -0.0)>,
#  <gurobi.Var X[1,9,8] (value -0.0)>,
#  <gurobi.Var X[1,9,10] (value -0.0)>,
#  <gurobi.Var X[1,9,11] (value -0.0)>,
#  <gurobi.Var X[1,9,12] (value -0.0)>,
#  <gurobi.Var X[1,9,13] (value -0.0)>,
#  <gurobi.Var X[1,9,14] (value -0.0)>,
#  <gurobi.Var X[1,9,15] (value -0.0)>,
#  <gurobi.Var X[1,9,16] (value -0.0)>,
#  <gurobi.Var X[1,10,1] (value -0.0)>,
#  <gurobi.Var X[1,10,2] (value -0.0)>,
#  <gurobi.Var X[1,10,3] (value -0.0)>,
#  <gurobi.Var X[1,10,4] (value -0.0)>,
#  <gurobi.Var X[1,10,5] (value -0.0)>,
#  <gurobi.Var X[1,10,6] (value -0.0)>,
#  <gurobi.Var X[1,10,7] (value -0.0)>,
#  <gurobi.Var X[1,10,8] (value -0.0)>,
#  <gurobi.Var X[1,10,9] (value -0.0)>,
#  <gurobi.Var X[1,10,11] (value -0.0)>,
#  <gurobi.Var X[1,10,12] (value -0.0)>,
#  <gurobi.Var X[1,10,13] (value -0.0)>,
#  <gurobi.Var X[1,10,14] (value -0.0)>,
#  <gurobi.Var X[1,10,15] (value -0.0)>,
#  <gurobi.Var X[1,10,16] (value -0.0)>,
#  <gurobi.Var X[1,11,1] (value -0.0)>,
#  <gurobi.Var X[1,11,2] (value 1.0)>,
#  <gurobi.Var X[1,11,3] (value -0.0)>,
#  <gurobi.Var X[1,11,4] (value -0.0)>,
#  <gurobi.Var X[1,11,5] (value -0.0)>,
#  <gurobi.Var X[1,11,6] (value -0.0)>,
#  <gurobi.Var X[1,11,7] (value -0.0)>,
#  <gurobi.Var X[1,11,8] (value -0.0)>,
#  <gurobi.Var X[1,11,9] (value -0.0)>,
#  <gurobi.Var X[1,11,10] (value -0.0)>,
#  <gurobi.Var X[1,11,12] (value -0.0)>,
#  <gurobi.Var X[1,11,13] (value 0.0)>,
#  <gurobi.Var X[1,11,14] (value -0.0)>,
#  <gurobi.Var X[1,11,15] (value -0.0)>,
#  <gurobi.Var X[1,11,16] (value -0.0)>,
#  <gurobi.Var X[1,12,1] (value -0.0)>,
#  <gurobi.Var X[1,12,2] (value -0.0)>,
#  <gurobi.Var X[1,12,3] (value -0.0)>,
#  <gurobi.Var X[1,12,4] (value -0.0)>,
#  <gurobi.Var X[1,12,5] (value -0.0)>,
#  <gurobi.Var X[1,12,6] (value 1.0)>,
#  <gurobi.Var X[1,12,7] (value -0.0)>,
#  <gurobi.Var X[1,12,8] (value -0.0)>,
#  <gurobi.Var X[1,12,9] (value -0.0)>,
#  <gurobi.Var X[1,12,10] (value -0.0)>,
#  <gurobi.Var X[1,12,11] (value -0.0)>,
#  <gurobi.Var X[1,12,13] (value 0.0)>,
#  <gurobi.Var X[1,12,14] (value -0.0)>,
#  <gurobi.Var X[1,12,15] (value -0.0)>,
#  <gurobi.Var X[1,12,16] (value -0.0)>,
#  <gurobi.Var X[1,13,1] (value -0.0)>,
#  <gurobi.Var X[1,13,2] (value -0.0)>,
#  <gurobi.Var X[1,13,3] (value 0.0)>,
#  <gurobi.Var X[1,13,4] (value -0.0)>,
#  <gurobi.Var X[1,13,5] (value -0.0)>,
#  <gurobi.Var X[1,13,6] (value -0.0)>,
#  <gurobi.Var X[1,13,7] (value 0.0)>,
#  <gurobi.Var X[1,13,8] (value -0.0)>,
#  <gurobi.Var X[1,13,9] (value -0.0)>,
#  <gurobi.Var X[1,13,10] (value -0.0)>,
#  <gurobi.Var X[1,13,11] (value -0.0)>,
#  <gurobi.Var X[1,13,12] (value -0.0)>,
#  <gurobi.Var X[1,13,14] (value -0.0)>,
#  <gurobi.Var X[1,13,15] (value -0.0)>,
#  <gurobi.Var X[1,13,16] (value 0.0)>,
#  <gurobi.Var X[1,14,1] (value -0.0)>,
#  <gurobi.Var X[1,14,2] (value -0.0)>,
#  <gurobi.Var X[1,14,3] (value -0.0)>,
#  <gurobi.Var X[1,14,4] (value -0.0)>,
#  <gurobi.Var X[1,14,5] (value -0.0)>,
#  <gurobi.Var X[1,14,6] (value -0.0)>,
#  <gurobi.Var X[1,14,7] (value -0.0)>,
#  <gurobi.Var X[1,14,8] (value -0.0)>,
#  <gurobi.Var X[1,14,9] (value -0.0)>,
#  <gurobi.Var X[1,14,10] (value -0.0)>,
#  <gurobi.Var X[1,14,11] (value -0.0)>,
#  <gurobi.Var X[1,14,12] (value -0.0)>,
#  <gurobi.Var X[1,14,13] (value -0.0)>,
#  <gurobi.Var X[1,14,15] (value -0.0)>,
#  <gurobi.Var X[1,14,16] (value -0.0)>,
#  <gurobi.Var X[1,15,1] (value -0.0)>,
#  <gurobi.Var X[1,15,2] (value -0.0)>,
#  <gurobi.Var X[1,15,3] (value -0.0)>,
#  <gurobi.Var X[1,15,4] (value -0.0)>,
#  <gurobi.Var X[1,15,5] (value -0.0)>,
#  <gurobi.Var X[1,15,6] (value -0.0)>,
#  <gurobi.Var X[1,15,7] (value -0.0)>,
#  <gurobi.Var X[1,15,8] (value -0.0)>,
#  <gurobi.Var X[1,15,9] (value -0.0)>,
#  <gurobi.Var X[1,15,10] (value -0.0)>,
#  <gurobi.Var X[1,15,11] (value -0.0)>,
#  <gurobi.Var X[1,15,12] (value -0.0)>,
#  <gurobi.Var X[1,15,13] (value -0.0)>,
#  <gurobi.Var X[1,15,14] (value -0.0)>,
#  <gurobi.Var X[1,15,16] (value -0.0)>,
#  <gurobi.Var X[1,16,1] (value -0.0)>,
#  <gurobi.Var X[1,16,2] (value -0.0)>,
#  <gurobi.Var X[1,16,3] (value -0.0)>,
#  <gurobi.Var X[1,16,4] (value -0.0)>,
#  <gurobi.Var X[1,16,5] (value -0.0)>,
#  <gurobi.Var X[1,16,6] (value -0.0)>,
#  <gurobi.Var X[1,16,7] (value 1.0)>,
#  <gurobi.Var X[1,16,8] (value -0.0)>,
#  <gurobi.Var X[1,16,9] (value -0.0)>,
#  <gurobi.Var X[1,16,10] (value -0.0)>,
#  <gurobi.Var X[1,16,11] (value -0.0)>,
#  <gurobi.Var X[1,16,12] (value -0.0)>,
#  <gurobi.Var X[1,16,13] (value 0.0)>,
#  <gurobi.Var X[1,16,14] (value -0.0)>,
#  <gurobi.Var X[1,16,15] (value -0.0)>,
#  <gurobi.Var X[1,0,1] (value 0.0)>,
#  <gurobi.Var X[1,0,2] (value 0.0)>,
#  <gurobi.Var X[1,0,3] (value 0.0)>,
#  <gurobi.Var X[1,0,4] (value 0.0)>,
#  <gurobi.Var X[1,0,5] (value 0.0)>,
#  <gurobi.Var X[1,0,6] (value 0.0)>,
#  <gurobi.Var X[1,0,7] (value 0.0)>,
#  <gurobi.Var X[1,0,8] (value 0.0)>,
#  <gurobi.Var X[1,0,9] (value 0.0)>,
#  <gurobi.Var X[1,0,10] (value 0.0)>,
#  <gurobi.Var X[1,0,11] (value 0.0)>,
#  <gurobi.Var X[1,0,12] (value 0.0)>,
#  <gurobi.Var X[1,0,13] (value 0.0)>,
#  <gurobi.Var X[1,0,14] (value 0.0)>,
#  <gurobi.Var X[1,0,15] (value 0.0)>,
#  <gurobi.Var X[1,0,16] (value 1.0)>,
#  <gurobi.Var X[1,1,-1] (value 1.0)>,
#  <gurobi.Var X[1,2,-1] (value -0.0)>,
#  <gurobi.Var X[1,3,-1] (value -0.0)>,
#  <gurobi.Var X[1,4,-1] (value -0.0)>,
#  <gurobi.Var X[1,5,-1] (value -0.0)>,
#  <gurobi.Var X[1,6,-1] (value -0.0)>,
#  <gurobi.Var X[1,7,-1] (value -0.0)>,
#  <gurobi.Var X[1,8,-1] (value -0.0)>,
#  <gurobi.Var X[1,9,-1] (value -0.0)>,
#  <gurobi.Var X[1,10,-1] (value -0.0)>,
#  <gurobi.Var X[1,11,-1] (value -0.0)>,
#  <gurobi.Var X[1,12,-1] (value -0.0)>,
#  <gurobi.Var X[1,13,-1] (value 0.0)>,
#  <gurobi.Var X[1,14,-1] (value -0.0)>,
#  <gurobi.Var X[1,15,-1] (value -0.0)>,
#  <gurobi.Var X[1,16,-1] (value -0.0)>,
#  <gurobi.Var X[2,1,2] (value -0.0)>,
#  <gurobi.Var X[2,1,3] (value -0.0)>,
#  <gurobi.Var X[2,1,4] (value -0.0)>,
#  <gurobi.Var X[2,1,5] (value -0.0)>,
#  <gurobi.Var X[2,1,6] (value -0.0)>,
#  <gurobi.Var X[2,1,7] (value -0.0)>,
#  <gurobi.Var X[2,1,8] (value -0.0)>,
#  <gurobi.Var X[2,1,9] (value -0.0)>,
#  <gurobi.Var X[2,1,10] (value -0.0)>,
#  <gurobi.Var X[2,1,11] (value -0.0)>,
#  <gurobi.Var X[2,1,12] (value -0.0)>,
#  <gurobi.Var X[2,1,13] (value -0.0)>,
#  <gurobi.Var X[2,1,14] (value -0.0)>,
#  <gurobi.Var X[2,1,15] (value -0.0)>,
#  <gurobi.Var X[2,1,16] (value -0.0)>,
#  <gurobi.Var X[2,2,1] (value -0.0)>,
#  <gurobi.Var X[2,2,3] (value -0.0)>,
#  <gurobi.Var X[2,2,4] (value -0.0)>,
#  <gurobi.Var X[2,2,5] (value -0.0)>,
#  <gurobi.Var X[2,2,6] (value -0.0)>,
#  <gurobi.Var X[2,2,7] (value -0.0)>,
#  <gurobi.Var X[2,2,8] (value -0.0)>,
#  <gurobi.Var X[2,2,9] (value -0.0)>,
#  <gurobi.Var X[2,2,10] (value -0.0)>,
#  <gurobi.Var X[2,2,11] (value -0.0)>,
#  <gurobi.Var X[2,2,12] (value -0.0)>,
#  <gurobi.Var X[2,2,13] (value -0.0)>,
#  <gurobi.Var X[2,2,14] (value -0.0)>,
#  <gurobi.Var X[2,2,15] (value -0.0)>,
#  <gurobi.Var X[2,2,16] (value -0.0)>,
#  <gurobi.Var X[2,3,1] (value -0.0)>,
#  <gurobi.Var X[2,3,2] (value -0.0)>,
#  <gurobi.Var X[2,3,4] (value -0.0)>,
#  <gurobi.Var X[2,3,5] (value -0.0)>,
#  <gurobi.Var X[2,3,6] (value -0.0)>,
#  <gurobi.Var X[2,3,7] (value -0.0)>,
#  <gurobi.Var X[2,3,8] (value -0.0)>,
#  <gurobi.Var X[2,3,9] (value -0.0)>,
#  <gurobi.Var X[2,3,10] (value -0.0)>,
#  <gurobi.Var X[2,3,11] (value -0.0)>,
#  <gurobi.Var X[2,3,12] (value -0.0)>,
#  <gurobi.Var X[2,3,13] (value 0.0)>,
#  <gurobi.Var X[2,3,14] (value -0.0)>,
#  <gurobi.Var X[2,3,15] (value 0.0)>,
#  <gurobi.Var X[2,3,16] (value -0.0)>,
#  <gurobi.Var X[2,4,1] (value -0.0)>,
#  <gurobi.Var X[2,4,2] (value -0.0)>,
#  <gurobi.Var X[2,4,3] (value -0.0)>,
#  <gurobi.Var X[2,4,5] (value 1.0)>,
#  <gurobi.Var X[2,4,6] (value -0.0)>,
#  <gurobi.Var X[2,4,7] (value -0.0)>,
#  <gurobi.Var X[2,4,8] (value -0.0)>,
#  <gurobi.Var X[2,4,9] (value -0.0)>,
#  <gurobi.Var X[2,4,10] (value -0.0)>,
#  <gurobi.Var X[2,4,11] (value -0.0)>,
#  <gurobi.Var X[2,4,12] (value -0.0)>,
#  <gurobi.Var X[2,4,13] (value -0.0)>,
#  <gurobi.Var X[2,4,14] (value -0.0)>,
#  <gurobi.Var X[2,4,15] (value -0.0)>,
#  <gurobi.Var X[2,4,16] (value -0.0)>,
#  <gurobi.Var X[2,5,1] (value -0.0)>,
#  <gurobi.Var X[2,5,2] (value -0.0)>,
#  <gurobi.Var X[2,5,3] (value -0.0)>,
#  <gurobi.Var X[2,5,4] (value -0.0)>,
#  <gurobi.Var X[2,5,6] (value -0.0)>,
#  <gurobi.Var X[2,5,7] (value -0.0)>,
#  <gurobi.Var X[2,5,8] (value -0.0)>,
#  <gurobi.Var X[2,5,9] (value 1.0)>,
#  <gurobi.Var X[2,5,10] (value -0.0)>,
#  <gurobi.Var X[2,5,11] (value -0.0)>,
#  <gurobi.Var X[2,5,12] (value -0.0)>,
#  <gurobi.Var X[2,5,13] (value -0.0)>,
#  <gurobi.Var X[2,5,14] (value -0.0)>,
#  <gurobi.Var X[2,5,15] (value -0.0)>,
#  <gurobi.Var X[2,5,16] (value -0.0)>,
#  <gurobi.Var X[2,6,1] (value -0.0)>,
#  <gurobi.Var X[2,6,2] (value -0.0)>,
#  <gurobi.Var X[2,6,3] (value -0.0)>,
#  <gurobi.Var X[2,6,4] (value -0.0)>,
#  <gurobi.Var X[2,6,5] (value -0.0)>,
#  <gurobi.Var X[2,6,7] (value -0.0)>,
#  <gurobi.Var X[2,6,8] (value -0.0)>,
#  <gurobi.Var X[2,6,9] (value -0.0)>,
#  <gurobi.Var X[2,6,10] (value -0.0)>,
#  <gurobi.Var X[2,6,11] (value -0.0)>,
#  <gurobi.Var X[2,6,12] (value -0.0)>,
#  <gurobi.Var X[2,6,13] (value -0.0)>,
#  <gurobi.Var X[2,6,14] (value -0.0)>,
#  <gurobi.Var X[2,6,15] (value 0.0)>,
#  <gurobi.Var X[2,6,16] (value -0.0)>,
#  <gurobi.Var X[2,7,1] (value -0.0)>,
#  <gurobi.Var X[2,7,2] (value -0.0)>,
#  <gurobi.Var X[2,7,3] (value -0.0)>,
#  <gurobi.Var X[2,7,4] (value -0.0)>,
#  <gurobi.Var X[2,7,5] (value -0.0)>,
#  <gurobi.Var X[2,7,6] (value -0.0)>,
#  <gurobi.Var X[2,7,8] (value -0.0)>,
#  <gurobi.Var X[2,7,9] (value -0.0)>,
#  <gurobi.Var X[2,7,10] (value -0.0)>,
#  <gurobi.Var X[2,7,11] (value -0.0)>,
#  <gurobi.Var X[2,7,12] (value -0.0)>,
#  <gurobi.Var X[2,7,13] (value -0.0)>,
#  <gurobi.Var X[2,7,14] (value -0.0)>,
#  <gurobi.Var X[2,7,15] (value -0.0)>,
#  <gurobi.Var X[2,7,16] (value -0.0)>,
#  <gurobi.Var X[2,8,1] (value -0.0)>,
#  <gurobi.Var X[2,8,2] (value -0.0)>,
#  <gurobi.Var X[2,8,3] (value -0.0)>,
#  <gurobi.Var X[2,8,4] (value -0.0)>,
#  <gurobi.Var X[2,8,5] (value -0.0)>,
#  <gurobi.Var X[2,8,6] (value -0.0)>,
#  <gurobi.Var X[2,8,7] (value -0.0)>,
#  <gurobi.Var X[2,8,9] (value -0.0)>,
#  <gurobi.Var X[2,8,10] (value -0.0)>,
#  <gurobi.Var X[2,8,11] (value -0.0)>,
#  <gurobi.Var X[2,8,12] (value -0.0)>,
#  <gurobi.Var X[2,8,13] (value -0.0)>,
#  <gurobi.Var X[2,8,14] (value 1.0)>,
#  <gurobi.Var X[2,8,15] (value -0.0)>,
#  <gurobi.Var X[2,8,16] (value -0.0)>,
#  <gurobi.Var X[2,9,1] (value -0.0)>,
#  <gurobi.Var X[2,9,2] (value -0.0)>,
#  <gurobi.Var X[2,9,3] (value -0.0)>,
#  <gurobi.Var X[2,9,4] (value -0.0)>,
#  <gurobi.Var X[2,9,5] (value -0.0)>,
#  <gurobi.Var X[2,9,6] (value -0.0)>,
#  <gurobi.Var X[2,9,7] (value -0.0)>,
#  <gurobi.Var X[2,9,8] (value 1.0)>,
#  <gurobi.Var X[2,9,10] (value -0.0)>,
#  <gurobi.Var X[2,9,11] (value -0.0)>,
#  <gurobi.Var X[2,9,12] (value -0.0)>,
#  <gurobi.Var X[2,9,13] (value -0.0)>,
#  <gurobi.Var X[2,9,14] (value -0.0)>,
#  <gurobi.Var X[2,9,15] (value -0.0)>,
#  <gurobi.Var X[2,9,16] (value -0.0)>,
#  <gurobi.Var X[2,10,1] (value -0.0)>,
#  <gurobi.Var X[2,10,2] (value -0.0)>,
#  <gurobi.Var X[2,10,3] (value -0.0)>,
#  <gurobi.Var X[2,10,4] (value 1.0)>,
#  <gurobi.Var X[2,10,5] (value -0.0)>,
#  <gurobi.Var X[2,10,6] (value -0.0)>,
#  <gurobi.Var X[2,10,7] (value -0.0)>,
#  <gurobi.Var X[2,10,8] (value -0.0)>,
#  <gurobi.Var X[2,10,9] (value -0.0)>,
#  <gurobi.Var X[2,10,11] (value -0.0)>,
#  <gurobi.Var X[2,10,12] (value -0.0)>,
#  <gurobi.Var X[2,10,13] (value -0.0)>,
#  <gurobi.Var X[2,10,14] (value -0.0)>,
#  <gurobi.Var X[2,10,15] (value -0.0)>,
#  <gurobi.Var X[2,10,16] (value -0.0)>,
#  <gurobi.Var X[2,11,1] (value -0.0)>,
#  <gurobi.Var X[2,11,2] (value -0.0)>,
#  <gurobi.Var X[2,11,3] (value -0.0)>,
#  <gurobi.Var X[2,11,4] (value -0.0)>,
#  <gurobi.Var X[2,11,5] (value -0.0)>,
#  <gurobi.Var X[2,11,6] (value 0.0)>,
#  <gurobi.Var X[2,11,7] (value -0.0)>,
#  <gurobi.Var X[2,11,8] (value -0.0)>,
#  <gurobi.Var X[2,11,9] (value -0.0)>,
#  <gurobi.Var X[2,11,10] (value -0.0)>,
#  <gurobi.Var X[2,11,12] (value -0.0)>,
#  <gurobi.Var X[2,11,13] (value -0.0)>,
#  <gurobi.Var X[2,11,14] (value -0.0)>,
#  <gurobi.Var X[2,11,15] (value 0.0)>,
#  <gurobi.Var X[2,11,16] (value -0.0)>,
#  <gurobi.Var X[2,12,1] (value -0.0)>,
#  <gurobi.Var X[2,12,2] (value -0.0)>,
#  <gurobi.Var X[2,12,3] (value -0.0)>,
#  <gurobi.Var X[2,12,4] (value -0.0)>,
#  <gurobi.Var X[2,12,5] (value -0.0)>,
#  <gurobi.Var X[2,12,6] (value -0.0)>,
#  <gurobi.Var X[2,12,7] (value -0.0)>,
#  <gurobi.Var X[2,12,8] (value -0.0)>,
#  <gurobi.Var X[2,12,9] (value -0.0)>,
#  <gurobi.Var X[2,12,10] (value -0.0)>,
#  <gurobi.Var X[2,12,11] (value -0.0)>,
#  <gurobi.Var X[2,12,13] (value -0.0)>,
#  <gurobi.Var X[2,12,14] (value -0.0)>,
#  <gurobi.Var X[2,12,15] (value -0.0)>,
#  <gurobi.Var X[2,12,16] (value -0.0)>,
#  <gurobi.Var X[2,13,1] (value -0.0)>,
#  <gurobi.Var X[2,13,2] (value -0.0)>,
#  <gurobi.Var X[2,13,3] (value 0.0)>,
#  <gurobi.Var X[2,13,4] (value -0.0)>,
#  <gurobi.Var X[2,13,5] (value -0.0)>,
#  <gurobi.Var X[2,13,6] (value -0.0)>,
#  <gurobi.Var X[2,13,7] (value -0.0)>,
#  <gurobi.Var X[2,13,8] (value -0.0)>,
#  <gurobi.Var X[2,13,9] (value -0.0)>,
#  <gurobi.Var X[2,13,10] (value -0.0)>,
#  <gurobi.Var X[2,13,11] (value -0.0)>,
#  <gurobi.Var X[2,13,12] (value -0.0)>,
#  <gurobi.Var X[2,13,14] (value -0.0)>,
#  <gurobi.Var X[2,13,15] (value -0.0)>,
#  <gurobi.Var X[2,13,16] (value -0.0)>,
#  <gurobi.Var X[2,14,1] (value -0.0)>,
#  <gurobi.Var X[2,14,2] (value -0.0)>,
#  <gurobi.Var X[2,14,3] (value -0.0)>,
#  <gurobi.Var X[2,14,4] (value -0.0)>,
#  <gurobi.Var X[2,14,5] (value -0.0)>,
#  <gurobi.Var X[2,14,6] (value -0.0)>,
#  <gurobi.Var X[2,14,7] (value -0.0)>,
#  <gurobi.Var X[2,14,8] (value -0.0)>,
#  <gurobi.Var X[2,14,9] (value -0.0)>,
#  <gurobi.Var X[2,14,10] (value -0.0)>,
#  <gurobi.Var X[2,14,11] (value 0.0)>,
#  <gurobi.Var X[2,14,12] (value -0.0)>,
#  <gurobi.Var X[2,14,13] (value 1.0)>,
#  <gurobi.Var X[2,14,15] (value 0.0)>,
#  <gurobi.Var X[2,14,16] (value -0.0)>,
#  <gurobi.Var X[2,15,1] (value -0.0)>,
#  <gurobi.Var X[2,15,2] (value -0.0)>,
#  <gurobi.Var X[2,15,3] (value -0.0)>,
#  <gurobi.Var X[2,15,4] (value -0.0)>,
#  <gurobi.Var X[2,15,5] (value -0.0)>,
#  <gurobi.Var X[2,15,6] (value -0.0)>,
#  <gurobi.Var X[2,15,7] (value -0.0)>,
#  <gurobi.Var X[2,15,8] (value -0.0)>,
#  <gurobi.Var X[2,15,9] (value -0.0)>,
#  <gurobi.Var X[2,15,10] (value 1.0)>,
#  <gurobi.Var X[2,15,11] (value -0.0)>,
#  <gurobi.Var X[2,15,12] (value -0.0)>,
#  <gurobi.Var X[2,15,13] (value -0.0)>,
#  <gurobi.Var X[2,15,14] (value -0.0)>,
#  <gurobi.Var X[2,15,16] (value -0.0)>,
#  <gurobi.Var X[2,16,1] (value -0.0)>,
#  <gurobi.Var X[2,16,2] (value -0.0)>,
#  <gurobi.Var X[2,16,3] (value 0.0)>,
#  <gurobi.Var X[2,16,4] (value -0.0)>,
#  <gurobi.Var X[2,16,5] (value -0.0)>,
#  <gurobi.Var X[2,16,6] (value 0.0)>,
#  <gurobi.Var X[2,16,7] (value -0.0)>,
#  <gurobi.Var X[2,16,8] (value -0.0)>,
#  <gurobi.Var X[2,16,9] (value -0.0)>,
#  <gurobi.Var X[2,16,10] (value -0.0)>,
#  <gurobi.Var X[2,16,11] (value -0.0)>,
#  <gurobi.Var X[2,16,12] (value -0.0)>,
#  <gurobi.Var X[2,16,13] (value -0.0)>,
#  <gurobi.Var X[2,16,14] (value -0.0)>,
#  <gurobi.Var X[2,16,15] (value -0.0)>,
#  <gurobi.Var X[2,0,1] (value 0.0)>,
#  <gurobi.Var X[2,0,2] (value 0.0)>,
#  <gurobi.Var X[2,0,3] (value 0.0)>,
#  <gurobi.Var X[2,0,4] (value 0.0)>,
#  <gurobi.Var X[2,0,5] (value 0.0)>,
#  <gurobi.Var X[2,0,6] (value 0.0)>,
#  <gurobi.Var X[2,0,7] (value 0.0)>,
#  <gurobi.Var X[2,0,8] (value 0.0)>,
#  <gurobi.Var X[2,0,9] (value 0.0)>,
#  <gurobi.Var X[2,0,10] (value 0.0)>,
#  <gurobi.Var X[2,0,11] (value 0.0)>,
#  <gurobi.Var X[2,0,12] (value 0.0)>,
#  <gurobi.Var X[2,0,13] (value 0.0)>,
#  <gurobi.Var X[2,0,14] (value 0.0)>,
#  <gurobi.Var X[2,0,15] (value 1.0)>,
#  <gurobi.Var X[2,0,16] (value 0.0)>,
#  <gurobi.Var X[2,1,-1] (value -0.0)>,
#  <gurobi.Var X[2,2,-1] (value -0.0)>,
#  <gurobi.Var X[2,3,-1] (value 0.0)>,
#  <gurobi.Var X[2,4,-1] (value -0.0)>,
#  <gurobi.Var X[2,5,-1] (value -0.0)>,
#  <gurobi.Var X[2,6,-1] (value 0.0)>,
#  <gurobi.Var X[2,7,-1] (value -0.0)>,
#  <gurobi.Var X[2,8,-1] (value -0.0)>,
#  <gurobi.Var X[2,9,-1] (value -0.0)>,
#  <gurobi.Var X[2,10,-1] (value -0.0)>,
#  <gurobi.Var X[2,11,-1] (value 0.0)>,
#  <gurobi.Var X[2,12,-1] (value -0.0)>,
#  <gurobi.Var X[2,13,-1] (value 1.0)>,
#  <gurobi.Var X[2,14,-1] (value -0.0)>,
#  <gurobi.Var X[2,15,-1] (value -0.0)>,
#  <gurobi.Var X[2,16,-1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode1_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode2_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode3_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode4_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode5_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode6_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode7_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode8_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode9_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode10_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode11_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode12_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode13_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode14_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode15_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode16_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode17_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode18_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode19_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode20_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode21_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode22_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode23_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyPickNode24_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode1_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode2_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode3_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode4_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode5_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode6_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode7_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode8_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode9_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode10_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode11_I1] (value 1.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL1,MyCoopNode12_I1] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode1_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode2_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode3_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode4_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode5_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode6_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode7_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode8_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode9_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode10_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode11_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode12_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode13_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode14_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode15_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode16_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode17_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode18_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode19_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode20_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode21_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode22_I2] (value 1.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode23_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyPickNode24_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode1_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode2_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode3_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode4_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode5_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode6_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode7_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode8_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode9_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode10_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode11_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL2,MyCoopNode12_I2] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode1_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode2_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode3_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode4_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode5_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode6_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode7_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode8_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode9_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode10_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode11_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode12_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode13_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode14_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode15_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode16_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode17_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode18_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode19_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode20_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode21_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode22_I3] (value 1.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode23_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyPickNode24_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode1_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode2_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode3_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode4_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode5_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode6_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode7_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode8_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode9_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode10_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode11_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode22_PL3,MyCoopNode12_I3] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode1_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode2_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode3_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode4_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode5_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode6_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode7_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode8_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode9_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode10_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode11_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode12_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode13_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode14_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode15_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode16_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode17_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode18_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode19_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode20_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode21_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode22_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode23_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyPickNode24_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode1_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode2_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode3_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode4_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode5_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode6_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode7_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode8_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode9_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode10_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode11_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL4,MyCoopNode12_I4] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode1_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode2_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode3_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode4_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode5_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode6_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode7_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode8_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode9_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode10_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode11_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode12_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode13_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode14_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode15_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode16_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode17_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode18_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode19_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode20_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode21_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode22_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode23_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyPickNode24_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode1_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode2_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode3_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode4_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode5_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode6_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode7_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode8_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode9_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode10_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode11_I5] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode8_PL5,MyCoopNode12_I5] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode1_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode2_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode3_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode4_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode5_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode6_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode7_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode8_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode9_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode10_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode11_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode12_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode13_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode14_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode15_I6] (value 1.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode16_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode17_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode18_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode19_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode20_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode21_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode22_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode23_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyPickNode24_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode1_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode2_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode3_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode4_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode5_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode6_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode7_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode8_I6] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode9_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode10_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode11_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL6,MyCoopNode12_I6] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode1_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode2_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode3_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode4_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode5_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode6_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode7_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode8_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode9_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode10_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode11_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode12_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode13_I7] (value 1.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode14_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode15_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode16_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode17_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode18_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode19_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode20_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode21_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode22_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode23_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyPickNode24_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode1_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode2_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode3_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode4_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode5_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode6_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode7_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode8_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode9_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode10_I7] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode11_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode13_PL7,MyCoopNode12_I7] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode1_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode2_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode3_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode4_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode5_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode6_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode7_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode8_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode9_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode10_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode11_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode12_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode13_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode14_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode15_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode16_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode17_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode18_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode19_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode20_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode21_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode22_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode23_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyPickNode24_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode1_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode2_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode3_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode4_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode5_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode6_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode7_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode8_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode9_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode10_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode11_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL8,MyCoopNode12_I8] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode1_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode2_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode3_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode4_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode5_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode6_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode7_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode8_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode9_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode10_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode11_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode12_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode13_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode14_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode15_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode16_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode17_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode18_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode19_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode20_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode21_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode22_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode23_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyPickNode24_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode1_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode2_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode3_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode4_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode5_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode6_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode7_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode8_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode9_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode10_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode11_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode12_PL9,MyCoopNode12_I9] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode1_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode2_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode3_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode4_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode5_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode6_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode7_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode8_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode9_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode10_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode11_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode12_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode13_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode14_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode15_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode16_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode17_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode18_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode19_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode20_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode21_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode22_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode23_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyPickNode24_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode1_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode2_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode3_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode4_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode5_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode6_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode7_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode8_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode9_I10] (value -0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode10_I10] (value 0.0)>,
#  <gurobi.Var Yp[1,MyPickNode15_PL10,MyCoopNode11_I10] (value -0.0)>,
#  ...]

# %%
cc
# Out:
# [2]

# %%
PsL
# Out:
# [1, 2]
